# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(color_codes=True)
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
test = pd.read_csv("C:/Users/Acer/Desktop/INDQ/Visual/26_Aug_P1")

# %%
test
# Out:
#         Unnamed: 0     index  ch1  ch2  ch3  dopp  UC  UC_count
# 0                0     0.000    0    0  0.0     0  -1         0
# 1                1     0.500    0    0  0.0     0  -1         0
# 2                2     0.110    0    0  0.0     0  -1         0
# 3                3     0.160    0    0  0.0     0  -1         0
# 4                4     0.210    0    0  0.0     0  -1         0
# ...            ...       ...  ...  ...  ...   ...  ..       ...
# 391261      391261  1983.620  107    0  0.0     0   0       141
# 391262      391262  1983.625  107    0  0.0     0   0       141
# 391263      391263  1983.630  107    0  0.0     0   0       141
# 391264      391264  1983.635  107    0  0.0     0   0       141
# 391265      391265  1983.640  107    0  0.0     0   0       141
#
# [391266 rows x 8 columns]

# %%
test.drop(['Unnamed: 0'], axis=1)
# Out:
#            index  ch1  ch2  ch3  dopp  UC  UC_count
# 0          0.000    0    0  0.0     0  -1         0
# 1          0.500    0    0  0.0     0  -1         0
# 2          0.110    0    0  0.0     0  -1         0
# 3          0.160    0    0  0.0     0  -1         0
# 4          0.210    0    0  0.0     0  -1         0
# ...          ...  ...  ...  ...   ...  ..       ...
# 391261  1983.620  107    0  0.0     0   0       141
# 391262  1983.625  107    0  0.0     0   0       141
# 391263  1983.630  107    0  0.0     0   0       141
# 391264  1983.635  107    0  0.0     0   0       141
# 391265  1983.640  107    0  0.0     0   0       141
#
# [391266 rows x 7 columns]

# %%
test.drop(['ch2'], axis=1)
# Out:
#         Unnamed: 0     index  ch1  ch3  dopp  UC  UC_count
# 0                0     0.000    0  0.0     0  -1         0
# 1                1     0.500    0  0.0     0  -1         0
# 2                2     0.110    0  0.0     0  -1         0
# 3                3     0.160    0  0.0     0  -1         0
# 4                4     0.210    0  0.0     0  -1         0
# ...            ...       ...  ...  ...   ...  ..       ...
# 391261      391261  1983.620  107  0.0     0   0       141
# 391262      391262  1983.625  107  0.0     0   0       141
# 391263      391263  1983.630  107  0.0     0   0       141
# 391264      391264  1983.635  107  0.0     0   0       141
# 391265      391265  1983.640  107  0.0     0   0       141
#
# [391266 rows x 7 columns]

# %%
test.drop(['Unnamed: 0'], axis=1)
# Out:
#            index  ch1  ch2  ch3  dopp  UC  UC_count
# 0          0.000    0    0  0.0     0  -1         0
# 1          0.500    0    0  0.0     0  -1         0
# 2          0.110    0    0  0.0     0  -1         0
# 3          0.160    0    0  0.0     0  -1         0
# 4          0.210    0    0  0.0     0  -1         0
# ...          ...  ...  ...  ...   ...  ..       ...
# 391261  1983.620  107    0  0.0     0   0       141
# 391262  1983.625  107    0  0.0     0   0       141
# 391263  1983.630  107    0  0.0     0   0       141
# 391264  1983.635  107    0  0.0     0   0       141
# 391265  1983.640  107    0  0.0     0   0       141
#
# [391266 rows x 7 columns]

# %%
test.drop([ 'ch1','ch2','ch3'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-22876515c15e> in <module>
# ----> 1 test.drop([ 'ch1','ch2','ch3'])
#
# G:\Anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# G:\Anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# G:\Anaconda\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
test
# Out:
#         Unnamed: 0     index  ch1  ch2  ch3  dopp  UC  UC_count
# 0                0     0.000    0    0  0.0     0  -1         0
# 1                1     0.500    0    0  0.0     0  -1         0
# 2                2     0.110    0    0  0.0     0  -1         0
# 3                3     0.160    0    0  0.0     0  -1         0
# 4                4     0.210    0    0  0.0     0  -1         0
# ...            ...       ...  ...  ...  ...   ...  ..       ...
# 391261      391261  1983.620  107    0  0.0     0   0       141
# 391262      391262  1983.625  107    0  0.0     0   0       141
# 391263      391263  1983.630  107    0  0.0     0   0       141
# 391264      391264  1983.635  107    0  0.0     0   0       141
# 391265      391265  1983.640  107    0  0.0     0   0       141
#
# [391266 rows x 8 columns]

# %%
test.remove(['Unnamed: 0', 'ch1','ch2','ch3'], axis =1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-96183429c4af> in <module>
# ----> 1 test.remove(['Unnamed: 0', 'ch1','ch2','ch3'], axis =1)
#
# G:\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'remove'

# %%
test
# Out:
#            index  ch1  ch2  ch3  dopp  UC  UC_count
# 0          0.000    0    0  0.0     0  -1         0
# 1          0.500    0    0  0.0     0  -1         0
# 2          0.110    0    0  0.0     0  -1         0
# 3          0.160    0    0  0.0     0  -1         0
# 4          0.210    0    0  0.0     0  -1         0
# ...          ...  ...  ...  ...   ...  ..       ...
# 391261  1983.620  107    0  0.0     0   0       141
# 391262  1983.625  107    0  0.0     0   0       141
# 391263  1983.630  107    0  0.0     0   0       141
# 391264  1983.635  107    0  0.0     0   0       141
# 391265  1983.640  107    0  0.0     0   0       141
#
# [391266 rows x 7 columns]

# %%
del test['ch1']

# %%
del test['ch2']

# %%
del test['ch3']

# %%
test
# Out:
#            index  dopp  UC  UC_count
# 0          0.000     0  -1         0
# 1          0.500     0  -1         0
# 2          0.110     0  -1         0
# 3          0.160     0  -1         0
# 4          0.210     0  -1         0
# ...          ...   ...  ..       ...
# 391261  1983.620     0   0       141
# 391262  1983.625     0   0       141
# 391263  1983.630     0   0       141
# 391264  1983.635     0   0       141
# 391265  1983.640     0   0       141
#
# [391266 rows x 4 columns]

# %%
test = test.rename(columns = {"index":"Timestamp"})

# %%
test
# Out:
#         Timestamp  dopp  UC  UC_count
# 0           0.000     0  -1         0
# 1           0.500     0  -1         0
# 2           0.110     0  -1         0
# 3           0.160     0  -1         0
# 4           0.210     0  -1         0
# ...           ...   ...  ..       ...
# 391261   1983.620     0   0       141
# 391262   1983.625     0   0       141
# 391263   1983.630     0   0       141
# 391264   1983.635     0   0       141
# 391265   1983.640     0   0       141
#
# [391266 rows x 4 columns]

# %%
sns.distplot(test['UC_count'])
plt.show()

# %%
sns.distplot(test['dopp'])
plt.show()
# Out:
# G:\Anaconda\lib\site-packages\seaborn\distributions.py:288: UserWarning: Data must have variance to compute a kernel density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.distplot(test['UC'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# G:\Anaconda\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-43-5e88eb8c2e34> in <module>
# ----> 1 sns.distplot(test['UC'])
#       2 plt.show()
#
# G:\Anaconda\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     231     if kde:
#     232         kde_color = kde_kws.pop("color", color)
# ...

# %%
sns.distplot(test['UC_count'], kde=False, rug=True);

# %%
sns.jointplot(test['UC'],test['Timestamp'])

# %%
sns.jointplot(test['UC'], test['UC_count'], kind="hex")

# %%
test
# Out:
#         Timestamp  dopp  UC  UC_count
# 0           0.000     0  -1         0
# 1           0.500     0  -1         0
# 2           0.110     0  -1         0
# 3           0.160     0  -1         0
# 4           0.210     0  -1         0
# ...           ...   ...  ..       ...
# 391261   1983.620     0   0       141
# 391262   1983.625     0   0       141
# 391263   1983.630     0   0       141
# 391264   1983.635     0   0       141
# 391265   1983.640     0   0       141
#
# [391266 rows x 4 columns]

# %%
sns.jointplot(test['UC'], test['dopp'], kind="hex")

# %%
sns.jointplot(test['Timestamp'], test['dopp'], kind="hex")

# %%
sns.jointplot(test['UC'], test['Timestamp'], kind="hex")

# %%
sns.jointplot(test['Timestamp'], test['UC'], kind="hex")

# %%
sns.jointplot(test['Timestamp'], test['UC_count'])

# %%
sns.jointplot(test['Timestamp'], test['UC_count'], kind="hex")

# %%
sns.jointplot(test['Timestamp'], test['UC_count'], kind="kde")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-6c6fc6136c7d> in <module>
# ----> 1 sns.jointplot(test['Timestamp'], test['UC_count'], kind="kde")
#
# G:\Anaconda\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2319         joint_kws.setdefault("shade", True)
#    2320         joint_kws.setdefault("cmap", cmap)
# -> 2321         grid.plot_joint(kdeplot, **joint_kws)
#    2322
#    2323         marginal_kws.setdefault("shade", True)
#
# G:\Anaconda\lib\site-packages\seaborn\axisgrid.py in plot_joint(self, func, **kwargs)
#    1783         """
#    1784         plt.sca(self.ax_joint)
# -> 1785         func(self.x, self.y, **kwargs)
#    1786
#    1787         return self
#
# ...

# %%
sns.pairplot(test[['UC', 'UC_count', 'dopp']])

# %%
test(['dopp'].nullvalue())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-e7ebcdcdca56> in <module>
# ----> 1 test(['dopp'].nullvalue())
#
# AttributeError: 'list' object has no attribute 'nullvalue'
