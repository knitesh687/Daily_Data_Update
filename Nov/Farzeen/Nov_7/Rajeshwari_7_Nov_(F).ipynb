# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Nov/Nov_7_F/Rajeshwari.csv')

# %%
del data['Unnamed: 0']

# %%
data.head()
# Out:
#    index  ch1  ch2   ch3  dopp   UC  UC_count  Manual_Uc_Status
# 0   0.00    0    0  3998     0    1         0                 0
# 1   0.50    0    0     0     0    1         0                 0
# 2   0.10    0    0     0     0    1         0                 0
# 3   0.15    0    0  3977     0  178         0                 0
# 4   0.20    0    0  3958     0   69         0                 0

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 682320 entries, 0 to 682319
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             682320 non-null  float64
#  1   ch1               682320 non-null  int64
#  2   ch2               682320 non-null  int64
#  3   ch3               682320 non-null  int64
#  4   dopp              682320 non-null  int64
#  5   UC                682320 non-null  int64
#  6   UC_count          682320 non-null  int64
#  7   Manual_Uc_Status  682320 non-null  int64
# dtypes: float64(1), int64(7)
# memory usage: 41.6 MB
#                index            ch1       ch2            ch3           dopp  \
# count  682320.000000  682320.000000  682320.0  682320.000000  682320.000000
# mean     1085.841069      61.548512       0.0     601.629175      22.269825
# std       716.204494      30.226067       0.0    1282.460633     173.962325
# min         0.000000       0.000000       0.0       0.000000       0.000000
# 25%       485.780250      65.000000       0.0       0.000000       0.000000
# 50%       970.854500      70.000000       0.0       0.000000       0.000000
# 75%      1663.555500      79.000000       0.0     360.000000       0.000000
# max      2551.990000     108.000000       0.0    4095.000000    2671.000000
#
#                   UC       UC_count  Manual_Uc_Status
# count  682320.000000  682320.000000     682320.000000
# mean       38.111218      38.107759          0.125676
# std        80.446346      16.780309          0.331484
# min         0.000000       0.000000          0.000000
# 25%         0.000000      32.000000          0.000000
# 50%         0.000000      38.000000          0.000000
# 75%        22.000000      45.000000          0.000000
# max       294.000000      63.000000          1.000000

# %%
plt.figure(figsize=(20,10))
plt.plot(data)
# Out:
# [<matplotlib.lines.Line2D at 0x202c0ab7f08>,
#  <matplotlib.lines.Line2D at 0x202c0aaba48>,
#  <matplotlib.lines.Line2D at 0x202c0aabc08>,
#  <matplotlib.lines.Line2D at 0x202c0aabdc8>,
#  <matplotlib.lines.Line2D at 0x202c0aa0088>,
#  <matplotlib.lines.Line2D at 0x202c0aa0308>,
#  <matplotlib.lines.Line2D at 0x202c0aa0508>,
#  <matplotlib.lines.Line2D at 0x202c0aa0788>]

# %%
plt.figure(figsize=(25,16))
uc = data['UC']
plt.plot(uc)

plt.figure(figsize=(25,16))
muc = data['Manual_Uc_Status']
plt.plot(muc)

# %%
sns.relplot(
    data=data,
    x="index", y="UC", hue="Manual_Uc_Status"
)

# %%
sns.pairplot(data[['index','ch1','ch2','ch3','dopp','UC','UC_count','Manual_Uc_Status']])

# %%
plt.figure(figsize=(10,8))
plt.title("Ch1")
new = data.copy()
# uc = data['UC']
b = data['ch1']
plt.plot(b)

plt.figure(figsize=(10,8))
plt.title("Ch2")
new = data.copy()
c = data['ch2']
# MuS = data['Manual_Uc_Status']
plt.plot(c)

plt.figure(figsize=(10,8))
plt.title("Ch3")
new = data.copy()
# uc = data['UC']
d = data['ch3']
plt.plot(d)

# %%
x = data['index']
z = data['UC']
#----------------------------------------------
plt.figure(figsize=(22,15))
plt.title('UC Vs index', fontsize=14)
plt.xlabel('index', fontsize=14)
plt.ylabel('UC', fontsize=14)
#----------------------------------------------
i = plt.plot(x, z, 'c')
plt.show(i)

# %%
x = data['index']
y = data['UC']
z = data['UC_count']
#----------------------------------------------
plt.figure(figsize=(22,15))
plt.title('UC, Uc_count Vs index', fontsize=14)
plt.xlabel('index', fontsize=14)
plt.ylabel('UC', fontsize=14)
#----------------------------------------------
i = plt.plot(x, y, 'c')
b =plt.plot(x, z, 'y')
plt.show(i,b)

# %%
plt.figure(figsize=(25,16))
uc = data['UC'].
plt.plot(uc)

plt.figure(figsize=(25,16))
muc = data['Manual_Uc_Status']
plt.plot(muc)
