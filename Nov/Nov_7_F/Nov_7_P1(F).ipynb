# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.reload_library()
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Nov/Nov_7_F/P1.csv')

# %%
data.head()
# Out:
#    index  ch1  ch2  ch3  dopp  UC  UC_count  Manual_Uc_Status
# 0   0.00    0    0    0     0   0         0                 0
# 1   0.40    0    0    0     0   0         0                 0
# 2   0.90    0    0    0     0   0         0                 0
# 3   0.24    0    0    0     0   0         0                 0
# 4   0.32    0    0    0     0   0         0                 0

# %%
del data['Unnamed: 0']

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 509282 entries, 0 to 509281
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             509282 non-null  float64
#  1   ch1               509282 non-null  int64
#  2   ch2               509282 non-null  int64
#  3   ch3               509282 non-null  int64
#  4   dopp              509282 non-null  int64
#  5   UC                509282 non-null  int64
#  6   UC_count          509282 non-null  int64
#  7   Manual_Uc_Status  509282 non-null  int64
# dtypes: float64(1), int64(7)
# memory usage: 31.1 MB
#                index            ch1       ch2            ch3           dopp  \
# count  509282.000000  509282.000000  509282.0  509282.000000  509282.000000
# mean      573.901573      80.950153       0.0     106.488916      12.337055
# std       371.438376      14.917275       0.0     470.890453      99.086330
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(data)

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC']
# MuS = data['Manual_Uc_Status']
plt.plot(uc)



plt.figure(figsize=(25,16))
new = data.copy()
# uc = data['UC']
MuS = data['Manual_Uc_Status']
plt.plot(MuS)

# %%
sns.relplot(
    data=data,
    x="index", y="UC", hue="Manual_Uc_Status"
)

# %%
sns.pairplot(data[['index','ch1','ch2','ch3','dopp','UC','UC_count','Manual_Uc_Status']])

# %%
plt.figure(figsize=(10,8))
plt.title("Ch1")
new = data.copy()
# uc = data['UC']
b = data['ch1']
plt.plot(b)

plt.figure(figsize=(10,8))
plt.title("Ch2")
new = data.copy()
c = data['ch2']
# MuS = data['Manual_Uc_Status']
plt.plot(c)

plt.figure(figsize=(10,8))
plt.title("Ch3")
new = data.copy()
# uc = data['UC']
d = data['ch3']
plt.plot(d)

# %%
plt.figure(figsize=(25,16))
plt.title("dopp")
new = data.copy()
e = data['dopp']
# MuS = data['Manual_Uc_Status']
plt.plot(e)

# %%
x = data['index']
z = data['UC']
#----------------------------------------------
plt.figure(figsize=(22,15))
plt.title('UC Vs index', fontsize=14)
plt.xlabel('index', fontsize=14)
plt.ylabel('UC', fontsize=14)
#----------------------------------------------
i = plt.plot(x, z, 'c')
plt.show(i)

# %%
x = data['index']
y = data['UC']
z = data['UC_count']
#----------------------------------------------
plt.figure(figsize=(22,15))
plt.title('UC, Uc_count Vs index', fontsize=14)
plt.xlabel('index', fontsize=14)
plt.ylabel('UC', fontsize=14)
#----------------------------------------------
i = plt.plot(x, y, 'c')
b =plt.plot(x, z, 'y')
plt.show(i,b)

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC'].iloc[1000:10000]
uc1 = data['UC'].iloc[10000:20000]
uc2 = data['UC'].iloc[20000:30000]
uc3 = data['UC'].iloc[30000:40000]
uc4 = data['UC'].iloc[50000:60000]
uc5 = data['UC'].iloc[60000:70000]
uc6 = data['UC'].iloc[70000:80000]
uc7 = data['UC'].iloc[90000:100000]
uc8 = data['UC'].iloc[100000:110000]
plt.plot(uc)
plt.plot(uc1)
plt.plot(uc2)
plt.plot(uc3)
plt.plot(uc4)
plt.plot(uc5)
plt.plot(uc6)
plt.plot(uc7)
plt.plot(uc8)


plt.figure(figsize=(25,16))
new = data.copy()
muc = data['Manual_Uc_Status'].iloc[1000:10000]
muc1 = data['Manual_Uc_Status'].iloc[10000:20000]
muc2 = data['Manual_Uc_Status'].iloc[20000:30000]
muc3 = data['Manual_Uc_Status'].iloc[30000:40000]
muc4 = data['Manual_Uc_Status'].iloc[50000:60000]
muc5 = data['Manual_Uc_Status'].iloc[60000:70000]
muc6 = data['Manual_Uc_Status'].iloc[70000:80000]
muc7 = data['Manual_Uc_Status'].iloc[90000:100000]
muc8 = data['Manual_Uc_Status'].iloc[100000:110000]
plt.plot(muc)
plt.plot(muc1)
plt.plot(muc2)
plt.plot(muc3)
plt.plot(muc4)
plt.plot(muc5)
plt.plot(muc6)
plt.plot(muc7)
plt.plot(muc8)

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC'].iloc[110000:120000]
uc1 = data['UC'].iloc[120000:130000]
uc2 = data['UC'].iloc[130000:140000]
uc3 = data['UC'].iloc[140000:150000]
uc4 = data['UC'].iloc[150000:160000]
uc5 = data['UC'].iloc[160000:170000]
uc6 = data['UC'].iloc[170000:180000]
uc7 = data['UC'].iloc[190000:200000]
uc8 = data['UC'].iloc[200000:210000]
plt.plot(uc)
plt.plot(uc1)
plt.plot(uc2)
plt.plot(uc3)
plt.plot(uc4)
plt.plot(uc5)
plt.plot(uc6)
plt.plot(uc7)
plt.plot(uc8)


plt.figure(figsize=(25,16))
new = data.copy()
muc = data['Manual_Uc_Status'].iloc[110000:120000]
muc1 = data['Manual_Uc_Status'].iloc[120000:130000]
muc2 = data['Manual_Uc_Status'].iloc[130000:140000]
muc3 = data['Manual_Uc_Status'].iloc[140000:150000]
muc4 = data['Manual_Uc_Status'].iloc[150000:160000]
muc5 = data['Manual_Uc_Status'].iloc[160000:170000]
muc6 = data['Manual_Uc_Status'].iloc[170000:180000]
muc7 = data['Manual_Uc_Status'].iloc[190000:200000]
muc8 = data['Manual_Uc_Status'].iloc[200000:210000]
plt.plot(muc)
plt.plot(muc1)
plt.plot(muc2)
plt.plot(muc3)
plt.plot(muc4)
plt.plot(muc5)
plt.plot(muc6)
plt.plot(muc7)
plt.plot(muc8)

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC'].iloc[210000:220000]
uc1 = data['UC'].iloc[220000:230000]
uc2 = data['UC'].iloc[230000:240000]
uc3 = data['UC'].iloc[240000:250000]
uc4 = data['UC'].iloc[250000:260000]
uc5 = data['UC'].iloc[260000:270000]
uc6 = data['UC'].iloc[270000:280000]
uc7 = data['UC'].iloc[280000:290000]
uc8 = data['UC'].iloc[290000:300000]
plt.plot(uc)
plt.plot(uc1)
plt.plot(uc2)
plt.plot(uc3)
plt.plot(uc4)
plt.plot(uc5)
plt.plot(uc6)
plt.plot(uc7)
plt.plot(uc8)


plt.figure(figsize=(25,16))
new = data.copy()
muc = data['Manual_Uc_Status'].iloc[210000:220000]
muc1 = data['Manual_Uc_Status'].iloc[220000:230000]
muc2 = data['Manual_Uc_Status'].iloc[230000:240000]
muc3 = data['Manual_Uc_Status'].iloc[240000:250000]
muc4 = data['Manual_Uc_Status'].iloc[250000:260000]
muc5 = data['Manual_Uc_Status'].iloc[260000:270000]
muc6 = data['Manual_Uc_Status'].iloc[270000:280000]
muc7 = data['Manual_Uc_Status'].iloc[280000:290000]
muc8 = data['Manual_Uc_Status'].iloc[290000:300000]
plt.plot(muc)
plt.plot(muc1)
plt.plot(muc2)
plt.plot(muc3)
plt.plot(muc4)
plt.plot(muc5)
plt.plot(muc6)
plt.plot(muc7)
plt.plot(muc8)

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc0=data['UC'].iloc[300000:310000]
uc = data['UC'].iloc[310000:320000]
uc1 = data['UC'].iloc[320000:330000]
uc2 = data['UC'].iloc[330000:340000]
uc3 = data['UC'].iloc[340000:350000]
uc4 = data['UC'].iloc[350000:360000]
uc5 = data['UC'].iloc[360000:370000]
uc6 = data['UC'].iloc[370000:380000]
uc7 = data['UC'].iloc[380000:390000]
uc8 = data['UC'].iloc[390000:400000]
plt.plot(uc0)
plt.plot(uc)
plt.plot(uc1)
plt.plot(uc2)
plt.plot(uc3)
plt.plot(uc4)
plt.plot(uc5)
plt.plot(uc6)
plt.plot(uc7)
plt.plot(uc8)


plt.figure(figsize=(25,16))
new = data.copy()
muc = data['Manual_Uc_Status'].iloc[300000:310000]
muc1 = data['Manual_Uc_Status'].iloc[310000:320000]
muc2 = data['Manual_Uc_Status'].iloc[320000:330000]
muc3 = data['Manual_Uc_Status'].iloc[330000:340000]
muc4 = data['Manual_Uc_Status'].iloc[340000:350000]
muc5 = data['Manual_Uc_Status'].iloc[350000:360000]
muc6 = data['Manual_Uc_Status'].iloc[360000:370000]
muc7= data['Manual_Uc_Status'].iloc[370000:380000]
muc8 = data['Manual_Uc_Status'].iloc[380000:390000]
muc9=data['Manual_Uc_Status'].iloc[390000:400000]
plt.plot(muc)
plt.plot(muc1)
plt.plot(muc2)
plt.plot(muc3)
plt.plot(muc4)
plt.plot(muc5)
plt.plot(muc6)
plt.plot(muc7)
plt.plot(muc8)
plt.plot(muc9)
