# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.reload_library()
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Oct/Oct_11/p2.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  index  ch1  ch2  ch3  dopp  UC  UC_count  Manual_Uc_Status
# 0           0   0.00    0    0  112     0   1         0                 0
# 1           1   0.50    0    0    0     0   1         0                 0
# 2           2   0.90    0    0  112     0   0         0                 0
# 3           3   0.14    0    0  108     0   0         0                 0
# 4           4   0.19    0    0  111     0   0         0                 0

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 725676 entries, 0 to 725675
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        725676 non-null  int64
#  1   index             725676 non-null  float64
#  2   ch1               725676 non-null  int64
#  3   ch2               725676 non-null  int64
#  4   ch3               725676 non-null  int64
#  5   dopp              725676 non-null  int64
#  6   UC                725676 non-null  int64
#  7   UC_count          725676 non-null  int64
#  8   Manual_Uc_Status  725676 non-null  int64
# dtypes: float64(1), int64(8)
# memory usage: 49.8 MB
#          Unnamed: 0          index            ch1       ch2            ch3  \
# count  725676.00000  725676.000000  725676.000000  725676.0  725676.000000
# mean   362837.50000    1461.804841      81.572036       0.0     133.606452
# ...

# %%
del data['Unnamed: 0']

# %% [markdown]
# # Overall Data

# %%
plt.figure(figsize=(20,16))
plt.plot(data)

# %% [markdown]
# # Relationship B/w UC and Manual_UC

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC']
# MuS = data['Manual_Uc_Status']
plt.plot(uc)



plt.figure(figsize=(25,16))
new = data.copy()
# uc = data['UC']
MuS = data['Manual_Uc_Status']
plt.plot(MuS)

# %% [markdown]
# # Relationship B/w UC and Manual_UC with Index

# %%
sns.relplot(
    data=data,
    x="index", y="UC", hue="Manual_Uc_Status"
)

# %% [markdown]
# # Relationship B/w Index, UC, UC_count and Manual_UC

# %%
sns.pairplot(data[['index', 'UC','UC_count', 'Manual_Uc_Status']])

# %%
sns.jointplot(x = data['UC'], y=data['UC_count'], data=data, kind = 'kde')

# %%
sns.jointplot(x = data['UC_count'], y=data['UC'], data=data, kind = 'hex')

# %%
# scatter', 'reg', 'resid', 'kde', or 'hex'

# %% [markdown]
# # Relationship B/W ''UC Vs Uc_count With index''

# %%
x = data['index']
y = data['UC']
z = data['UC_count']
#----------------------------------------------
plt.figure(figsize=(22,15))
plt.title('UC, Uc_count Vs index', fontsize=14)
plt.xlabel('index', fontsize=14)
plt.ylabel('UC', fontsize=14)
#----------------------------------------------
i = plt.plot(x, y, 'c')
b =plt.plot(x, z, 'y')
plt.show(i,b)

# %% [markdown]
# # Relationship B/w UC vs Index

# %%
x = data['index']
y = data['UC']
#-----------------------------------
plt.figure(figsize=(22,15))
plt.title('UC Vs index', fontsize=14)
plt.xlabel('index', fontsize=14)
plt.ylabel('UC', fontsize=14)
#-----------------------------------
i = plt.plot(x, y, 'c')
plt.show(i)

# %% [markdown]
# # Relationship B/w UC_count vs Index

# %%
x = data['index']
z = data['UC_count']
#----------------------------
plt.figure(figsize=(22,15))
plt.title('Uc_count Vs index', fontsize=14)
plt.xlabel('index', fontsize=14)
plt.ylabel('UC', fontsize=14)
#-------------------------------
b =plt.plot(x, z, 'y')
plt.show(b)
