# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.reload_library()
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Oct/Oct_21/f_p1.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  index  ch1  ch2  ch3  dopp  UC  UC_count  Manual_Uc_Status
# 0           0   0.10    0    0  319     0   1         0                 0
# 1           1   0.50    0    0  333     0   0         0                 0
# 2           2   0.12    0    0  323     0   0         0                 0
# 3           3   0.17    0    0  314     0   0         0                 0
# 4           4   0.21    0    0  310     0   0         0                 0

# %%
del data['Unnamed: 0']

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370134 entries, 0 to 370133
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             370134 non-null  float64
#  1   ch1               370134 non-null  int64
#  2   ch2               370134 non-null  int64
#  3   ch3               370134 non-null  int64
#  4   dopp              370134 non-null  int64
#  5   UC                370134 non-null  int64
#  6   UC_count          370134 non-null  int64
#  7   Manual_Uc_Status  370134 non-null  int64
# dtypes: float64(1), int64(7)
# memory usage: 22.6 MB
#                index            ch1       ch2            ch3           dopp  \
# count  370134.000000  370134.000000  370134.0  370134.000000  370134.000000
# mean      946.780962      57.365749       0.0     219.463386      14.905097
# std       546.434794      27.852485       0.0     694.920064     166.338164
# min         0.100000       0.000000       0.0       0.000000       0.000000
# 25%       473.467250      64.000000       0.0       0.000000       0.000000
# 50%       946.799000      68.000000       0.0       0.000000       0.000000
# 75%      1420.206000      73.000000       0.0     113.000000       0.000000
# max      1892.960000      98.000000       0.0    4080.000000    2672.000000
#
#                   UC       UC_count  Manual_Uc_Status
# count  370134.000000  370134.000000     370134.000000
# mean       13.693557      23.303277          0.244971
# std        43.857075      11.844959          0.430070
# min         0.000000       0.000000          0.000000
# 25%         0.000000      14.000000          0.000000
# 50%         0.000000      25.000000          0.000000
# 75%         7.000000      31.000000          0.000000
# max       256.000000      48.000000          1.000000

# %%
plt.figure(figsize=(20,10))
plt.plot(data)
# Out:
# [<matplotlib.lines.Line2D at 0x1c3a30ef788>,
#  <matplotlib.lines.Line2D at 0x1c3a30dd108>,
#  <matplotlib.lines.Line2D at 0x1c3a30dd2c8>,
#  <matplotlib.lines.Line2D at 0x1c3a30dd488>,
#  <matplotlib.lines.Line2D at 0x1c3a30dd688>,
#  <matplotlib.lines.Line2D at 0x1c3a30dd8c8>,
#  <matplotlib.lines.Line2D at 0x1c3a30dda88>,
#  <matplotlib.lines.Line2D at 0x1c3a30ddcc8>]

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC']
plt.plot(uc)



plt.figure(figsize=(25,16))
new = data.copy()
MuS = data['Manual_Uc_Status']
plt.plot(MuS)

# %%
sns.relplot(
    data=data,
    x="index", y="UC", hue="Manual_Uc_Status"
)

# %%
sns.pairplot(data[['index', 'UC','UC_count', 'Manual_Uc_Status']])

# %%
plt.figure(figsize=(10,8))
plt.title("Ch1")
new = data.copy()
b = data['ch1']
plt.plot(b)

plt.figure(figsize=(10,8))
plt.title("Ch2")
new = data.copy()
c = data['ch2']
plt.plot(c)

plt.figure(figsize=(10,8))
plt.title("Ch3")
new = data.copy()
d = data['ch3']
plt.plot(d)

# %%
plt.figure(figsize=(25,16))
plt.title("dopp")
new = data.copy()
e = data['dopp']
plt.plot(e)

# %%
plt.figure(figsize=(25,16))
plt.title("UC")
new = data.copy()
f = data['UC']
plt.plot(f)
