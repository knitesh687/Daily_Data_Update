# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.reload_library()
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
data = pd.read_csv('f_p1.csv', index_col='index',
                       parse_dates=True)
 
# Printing dataFrame
data.head()
# Out:
#        Unnamed: 0  ch1  ch2  ch3  dopp  UC  UC_count  Manual_Uc_Status
# index
# 0.10            0    0    0  319     0   1         0                 0
# 0.50            1    0    0  333     0   0         0                 0
# 0.12            2    0    0  323     0   0         0                 0
# 0.17            3    0    0  314     0   0         0                 0
# 0.21            4    0    0  310     0   0         0                 0

# %%
del data['Unnamed: 0']

# %%
data.head()
# Out:
#        ch1  ch2  ch3  dopp  UC  UC_count  Manual_Uc_Status
# index
# 0.10     0    0  319     0   1         0                 0
# 0.50     0    0  333     0   0         0                 0
# 0.12     0    0  323     0   0         0                 0
# 0.17     0    0  314     0   0         0                 0
# 0.21     0    0  310     0   0         0                 0

# %%
# uc = data['UC'].iloc[0:5000]
df = data['UC'].iloc[0:197].to_frame()
 
# calculating simple moving average
# using .rolling(window).mean() ,
# with window size = 30
df['SMA30'] = df['UC'].rolling(30).mean()
 
# removing all the NULL values using
# dropna() method
df.dropna(inplace=True)
 
# printing Dataframe
df
# Out:
#         UC     SMA30
# index
# 0.150    0  2.666667
# 0.155    0  2.633333
# 0.160    7  2.866667
# 0.165    0  2.866667
# 0.170    2  2.933333
# ...     ..       ...
# 10.215   0  0.000000
# 10.220   0  0.000000
# 10.227   0  0.000000
# 10.231   0  0.000000
# 10.237   0  0.000000
#
# [1971 rows x 2 columns]

# %%
df[['UC', 'SMA30']].plot(label='UC',
                                  figsize=(25, 12))

# %%
# uc = data['UC'].iloc[0:5000]
df = data['UC'].iloc[0:2000].to_frame()
 
# calculating simple moving average
# using .rolling(window).mean() ,
# with window size = 30
df['SMA100'] = df['UC'].rolling(30).mean()
 
# removing all the NULL values using
# dropna() method
df.dropna(inplace=True)
 
# printing Dataframe
df
# Out:
#       UC    SMA100
# 29     0  2.666667
# 30     0  2.633333
# 31     7  2.866667
# 32     0  2.866667
# 33     2  2.933333
# ...   ..       ...
# 1995   0  0.000000
# 1996   0  0.000000
# 1997   0  0.000000
# 1998   0  0.000000
# 1999   0  0.000000
#
# [1971 rows x 2 columns]

# %%
df[['UC', 'SMA100']].plot(label='UC',
                                  figsize=(25, 12))

# %%
data = pd.read_csv('f_p1.csv',
                       parse_dates=True)
 
# Printing dataFrame
del data['Unnamed: 0']
data.head()
# Out:
#    index  ch1  ch2  ch3  dopp  UC  UC_count  Manual_Uc_Status
# 0   0.10    0    0  319     0   1         0                 0
# 1   0.50    0    0  333     0   0         0                 0
# 2   0.12    0    0  323     0   0         0                 0
# 3   0.17    0    0  314     0   0         0                 0
# 4   0.21    0    0  310     0   0         0                 0

# %%
# uc = data['UC'].iloc[0:5000]
df = data['UC'].iloc[0:5000].to_frame()
 
# calculating simple moving average
# using .rolling(window).mean() ,
# with window size = 30
df['SMA30'] = df['UC'].rolling(30).mean()
 
# removing all the NULL values using
# dropna() method
df.dropna(inplace=True)
 
# printing Dataframe
df
# Out:
#       UC     SMA30
# 29     0  2.666667
# 30     0  2.633333
# 31     7  2.866667
# 32     0  2.866667
# 33     2  2.933333
# ...   ..       ...
# 4995   0  0.000000
# 4996   1  0.033333
# 4997   1  0.066667
# 4998   1  0.100000
# 4999   1  0.133333
#
# [4971 rows x 2 columns]

# %%
df[['UC', 'SMA30']].plot(label='UC',
                                  figsize=(25, 12))

# %%
import pandas as pd
 
# importing numpy as np
# for Mathematical calculations
import numpy as np
 
# importing pyplot from matplotlib as plt
# for plotting graphs
import matplotlib.pyplot as plt
plt.style.use('default')
# %matplotlib inline



df = data['UC'].iloc[0:5000].to_frame()
 
# calculating simple moving average
# using .rolling(window).mean() ,
# with window size = 30
df['SMA30'] = df['UC'].rolling(30).mean()
 
# removing all the NULL values using
# dropna() method
df.dropna(inplace=True)

# %%
df = data['UC'].iloc[0:10000].to_frame()
 
# calculating cumulative moving
# average using .expanding().mean()
df['CMA50'] = df['UC'].expanding().mean()
 
# printing Dataframe
df
# Out:
#       UC      CMA50
# 0      1   1.000000
# 1      0   0.500000
# 2      0   0.333333
# 3      0   0.250000
# 4      0   0.200000
# ...   ..        ...
# 9995   0  30.260904
# 9996   0  30.257877
# 9997   0  30.254851
# 9998   0  30.251825
# 9999   0  30.248800
#
# [10000 rows x 2 columns]

# %%
df[['UC', 'CMA50']].plot(label='UC',
                                  figsize=(25, 12))

# %% [markdown]
# # Main Code For Simple Moving Average and Cumulative Moving Average

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
# %matplotlib inline

# %%
data = pd.read_csv('f_p1.csv',
                       parse_dates=True)
data.head()
# Out:
#    Unnamed: 0  index  ch1  ch2  ch3  dopp  UC  UC_count  Manual_Uc_Status
# 0           0   0.10    0    0  319     0   1         0                 0
# 1           1   0.50    0    0  333     0   0         0                 0
# 2           2   0.12    0    0  323     0   0         0                 0
# 3           3   0.17    0    0  314     0   0         0                 0
# 4           4   0.21    0    0  310     0   0         0                 0

# %%
df = data['UC'].iloc[0:1000].to_frame()


# with window size = 30
df['SMA30'] = df['UC'].rolling(30).mean()

# removing all the NULL values using
df.dropna(inplace=True)
df
# Out:
#         UC       SMA30
# index
# 0.150    0    2.666667
# 0.155    0    2.633333
# 0.160    7    2.866667
# 0.165    0    2.866667
# 0.170    2    2.933333
# ...    ...         ...
# 5.970  253  253.200000
# 5.103  253  253.166667
# 5.107  253  253.166667
# 5.112  253  253.166667
# 5.118  253  253.166667
#
# [971 rows x 2 columns]

# %% [markdown]
# # Cumulative Moving Average (CMA)

# %%
# importing time-series data
data = pd.read_csv('f_p1.csv',
                       
                       parse_dates=True)
 
# Printing dataFrame
data.head()
# Out:
#    Unnamed: 0  index  ch1  ch2  ch3  dopp  UC  UC_count  Manual_Uc_Status
# 0           0   0.10    0    0  319     0   1         0                 0
# 1           1   0.50    0    0  333     0   0         0                 0
# 2           2   0.12    0    0  323     0   0         0                 0
# 3           3   0.17    0    0  314     0   0         0                 0
# 4           4   0.21    0    0  310     0   0         0                 0

# %%
df = data['UC'].iloc[0:5000].to_frame()


# with window size = 30
df['SMA50'] = df['UC'].rolling(50).mean()
df['CMA50'] = df['UC'].rolling(50).mean()
df['CMA50'] = df['UC'].rolling(50).mean()

# removing all the NULL values using
df.dropna(inplace=True)
df
# Out:
#       UC  SMA50  CMA50
# 49     0   2.28   2.28
# 50     1   2.28   2.28
# 51     8   2.44   2.44
# 52    17   2.78   2.78
# 53    17   3.12   3.12
# ...   ..    ...    ...
# 4995   0   0.28   0.28
# 4996   1   0.26   0.26
# 4997   1   0.24   0.24
# 4998   1   0.24   0.24
# 4999   1   0.24   0.24
#
# [4951 rows x 3 columns]

# %%
df[['UC', 'CMA100']].plot(label='UC',
                                  figsize=(25, 12))
