# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.reload_library()
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Oct/Oct_24/p2.csv')

# %%
data.head()
# Out:
#    Unnamed: 0    index  ch1  ch2    ch3  dopp  UC  UC_count  Manual_Uc_Status
# 0           0  924.689    0    0  323.0     0  20        52                 0
# 1           1  924.694    0    0  329.0     0  21        52                 0
# 2           2  924.699    0    0  336.0     0  21        52                 0
# 3           3  924.704    0    0  351.0     0  22        52                 0
# 4           4  924.709    0    0  368.0     0  23        52                 0

# %%
del data['Unnamed: 0']

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131249 entries, 0 to 131248
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             131249 non-null  float64
#  1   ch1               131249 non-null  int64
#  2   ch2               131249 non-null  int64
#  3   ch3               131249 non-null  float64
#  4   dopp              131249 non-null  int64
#  5   UC                131249 non-null  int64
#  6   UC_count          131249 non-null  int64
#  7   Manual_Uc_Status  131249 non-null  int64
# dtypes: float64(2), int64(6)
# memory usage: 8.0 MB
#                index       ch1       ch2            ch3      dopp  \
# count  131249.000000  131249.0  131249.0  131249.000000  131249.0
# mean     1255.360007       0.0       0.0    1137.462289       0.0
# std       189.550813       0.0       0.0    1188.277368       0.0
# min       924.689000       0.0       0.0       0.000000       0.0
# 25%      1091.350000       0.0       0.0     294.000000       0.0
# 50%      1255.425000       0.0       0.0     669.000000       0.0
# 75%      1419.497000       0.0       0.0    1517.000000       0.0
# max      1583.960000       0.0       0.0    4095.000000       0.0
#
#                   UC       UC_count  Manual_Uc_Status
# count  131249.000000  131249.000000     131249.000000
# mean       70.995649      97.030857          0.506571
# std        74.080633      37.122781          0.499959
# min         0.000000      52.000000          0.000000
# 25%        18.000000      70.000000          0.000000
# 50%        42.000000      86.000000          1.000000
# 75%        95.000000     116.000000          1.000000
# max       255.000000     181.000000          1.000000

# %%
plt.figure(figsize=(20,10))
plt.plot(data)
# Out:
# [<matplotlib.lines.Line2D at 0x2675183afc8>,
#  <matplotlib.lines.Line2D at 0x26751830208>,
#  <matplotlib.lines.Line2D at 0x267518303c8>,
#  <matplotlib.lines.Line2D at 0x26751830588>,
#  <matplotlib.lines.Line2D at 0x26751830788>,
#  <matplotlib.lines.Line2D at 0x26751830988>,
#  <matplotlib.lines.Line2D at 0x26751830b48>,
#  <matplotlib.lines.Line2D at 0x26751830d88>]

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC']
plt.plot(uc)



plt.figure(figsize=(25,16))
new = data.copy()
MuS = data['Manual_Uc_Status']
plt.plot(MuS)

# %%
sns.relplot(
    data=data,
    x="index", y="UC", hue="Manual_Uc_Status"
)

# %%
x = data['index']
z = data['UC']
#----------------------------------------------
plt.figure(figsize=(22,15))
plt.title('UC Vs index', fontsize=14)
plt.xlabel('index', fontsize=14)
plt.ylabel('UC', fontsize=14)
#----------------------------------------------
i = plt.plot(x, z, 'c')
plt.show(i)

# %%
x = data['index']
y = data['UC']
z = data['UC_count']
#----------------------------------------------
plt.figure(figsize=(22,15))
plt.title('UC, Uc_count Vs index', fontsize=14)
plt.xlabel('index', fontsize=14)
plt.ylabel('UC', fontsize=14)
#----------------------------------------------
i = plt.plot(x, y, 'c')
b =plt.plot(x, z, 'y')
plt.show(i,b)

# %%
plt.figure(figsize=(10,8))
plt.title("Ch1")
new = data.copy()
b = data['ch1']
plt.plot(b)

plt.figure(figsize=(10,8))
plt.title("Ch2")
new = data.copy()
c = data['ch2']
plt.plot(c)

plt.figure(figsize=(10,8))
plt.title("Ch3")
new = data.copy()
d = data['ch3']
plt.plot(d)

# %%
plt.figure(figsize=(25,16))
plt.title("dopp")
new = data.copy()
e = data['dopp']
plt.plot(e)

# %%
plt.figure(figsize=(25,16))
plt.title("UC")
new = data.copy()
f = data['UC']
plt.plot(f)

# %%
sns.pairplot(data[['index','ch1','ch2','ch3','dopp','UC','UC_count','Manual_Uc_Status']])
