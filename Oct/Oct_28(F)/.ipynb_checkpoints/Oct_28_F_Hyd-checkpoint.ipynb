# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.reload_library()
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Oct/Oct_28(F)/p1.json'))

# %%
df = data.copy()
del df["raw_data"]["0"]
# data_json["raw_data"]
df = pd.DataFrame(data["raw_data"])

dataf = df.T
data_x = dataf.reset_index()
# data_x = data_x.iloc[:,0]
data_x
file_name = 'p1'
data_x.to_csv(path_or_buf='C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Oct/Oct_28(F)/'+file_name+'.csv')

# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Oct/Oct_28(F)/p1.csv')

# %%
del data['Unnamed: 0']

# %%
data.head()
# Out:
#    index  ch1  ch2   ch3  dopp   UC  UC_count  Manual_Uc_Status
# 0   0.10    0    0  1187     0    1         0                 0
# 1   0.50    0    0  1191     0  297         0                 0
# 2   0.13    0    0  1191     0   42         0                 0
# 3   0.19    0    0  1200     0  170         0                 0
# 4   0.26    0    0  1194     0  278         0                 0

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 434128 entries, 0 to 434127
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             434128 non-null  float64
#  1   ch1               434128 non-null  int64
#  2   ch2               434128 non-null  int64
#  3   ch3               434128 non-null  int64
#  4   dopp              434128 non-null  int64
#  5   UC                434128 non-null  int64
#  6   UC_count          434128 non-null  int64
#  7   Manual_Uc_Status  434128 non-null  int64
# dtypes: float64(1), int64(7)
# memory usage: 26.5 MB
#                index            ch1       ch2            ch3           dopp  \
# count  434128.000000  434128.000000  434128.0  434128.000000  434128.000000
# mean     1119.946142      78.178252       0.0     864.253792      18.300434
# std       645.319512      13.688608       0.0     789.385128     191.404424
# min         0.100000       0.000000       0.0       0.000000       0.000000
# 25%       561.319500      81.000000       0.0       0.000000       0.000000
# 50%      1120.724000      81.000000       0.0     978.000000       0.000000
# 75%      1679.325500      81.000000       0.0    1261.000000       0.000000
# max      2235.960000      95.000000       0.0    4055.000000    2737.000000
#
#                   UC       UC_count  Manual_Uc_Status
# count  434128.000000  434128.000000     434128.000000
# mean       31.560455      52.517534          0.183778
# std        42.536011      30.668332          0.387303
# min         0.000000       0.000000          0.000000
# 25%         0.000000      27.000000          0.000000
# 50%        20.000000      28.000000          0.000000
# 75%        42.000000      88.000000          0.000000
# max       297.000000      94.000000          1.000000

# %%
plt.figure(figsize=(20,10))
plt.plot(data)
# Out:
# [<matplotlib.lines.Line2D at 0x19258e70708>,
#  <matplotlib.lines.Line2D at 0x1922d8a4b88>,
#  <matplotlib.lines.Line2D at 0x1922d8a4d48>,
#  <matplotlib.lines.Line2D at 0x1922d8a4f08>,
#  <matplotlib.lines.Line2D at 0x1922d60c1c8>,
#  <matplotlib.lines.Line2D at 0x1922d60c448>,
#  <matplotlib.lines.Line2D at 0x1922d60c648>,
#  <matplotlib.lines.Line2D at 0x1922d60c8c8>]

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC']
# MuS = data['Manual_Uc_Status']
plt.plot(uc)



plt.figure(figsize=(25,16))
new = data.copy()
# uc = data['UC']
MuS = data['Manual_Uc_Status']
plt.plot(MuS)

# %%
sns.relplot(
    data=data,
    x="index", y="UC", hue="Manual_Uc_Status"
)

# %%
sns.pairplot(data[['index','ch1','ch2','ch3','dopp','UC','UC_count','Manual_Uc_Status']])

# %%
x = data['index']
z = data['UC']
#----------------------------------------------
plt.figure(figsize=(22,15))
plt.title('UC Vs index', fontsize=14)
plt.xlabel('index', fontsize=14)
plt.ylabel('UC', fontsize=14)
#----------------------------------------------
i = plt.plot(x, z, 'c')
plt.show(i)

# %%
x = data['index']
y = data['UC']
z = data['UC_count']
#----------------------------------------------
plt.figure(figsize=(22,15))
plt.title('UC, Uc_count Vs index', fontsize=14)
plt.xlabel('index', fontsize=14)
plt.ylabel('UC', fontsize=14)
#----------------------------------------------
i = plt.plot(x, y, 'c')
b =plt.plot(x, z, 'y')
plt.show(i,b)

# %%
plt.figure(figsize=(10,8))
plt.title("Ch1")
new = data.copy()
b = data['ch1']
plt.plot(b)

plt.figure(figsize=(10,8))
plt.title("Ch2")
new = data.copy()
c = data['ch2']
plt.plot(c)

plt.figure(figsize=(10,8))
plt.title("Ch3")
new = data.copy()
d = data['ch3']
plt.plot(d)

# %%
plt.figure(figsize=(25,16))
plt.title("dopp")
new = data.copy()
e = data['dopp']
plt.plot(e)
