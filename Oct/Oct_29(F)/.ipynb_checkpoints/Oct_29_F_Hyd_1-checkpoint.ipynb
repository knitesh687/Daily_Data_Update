# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.reload_library()
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Oct/Oct_29(F)/p1.json'))

# %%
df = data.copy()
del df["raw_data"]["0"]
# data_json["raw_data"]
df = pd.DataFrame(data["raw_data"])

dataf = df.T
data_x = dataf.reset_index()
# data_x = data_x.iloc[:,0]
data_x
file_name = 'p1'
data_x.to_csv(path_or_buf='C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Oct/Oct_29(F)/'+file_name+'.csv')

# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Oct/Oct_29(F)/p1.csv')

# %%
del data['Unnamed: 0']

# %%
data.head()
# Out:
#    index  ch1  ch2  ch3  dopp   UC  UC_count  Manual_Uc_Status
# 0   0.10    0    0  848     0    1         0                 0
# 1   0.50    0    0  839     0    0         0                 0
# 2   0.11    0    0  831     0   26         0                 0
# 3   0.16    0    0  848     0  255         0                 0
# 4   0.21    0    0  848     0  255         0                 0

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268634 entries, 0 to 268633
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             268634 non-null  float64
#  1   ch1               268634 non-null  int64
#  2   ch2               268634 non-null  int64
#  3   ch3               268634 non-null  int64
#  4   dopp              268634 non-null  int64
#  5   UC                268634 non-null  int64
#  6   UC_count          268634 non-null  int64
#  7   Manual_Uc_Status  268634 non-null  int64
# dtypes: float64(1), int64(7)
# memory usage: 16.4 MB
#                index            ch1       ch2            ch3           dopp  \
# count  268634.000000  268634.000000  268634.0  268634.000000  268634.000000
# mean      690.180791      78.105984       0.0     556.184481       9.237811
# std       398.536694      12.038632       0.0     471.688213     130.382383
# min         0.100000       0.000000       0.0     195.000000       0.000000
# 25%       344.980250      67.000000       0.0     402.000000       0.000000
# 50%       690.264000      75.000000       0.0     471.000000       0.000000
# 75%      1035.305000      88.000000       0.0     559.000000       0.000000
# max      1380.940000     110.000000       0.0    4071.000000    2713.000000
#
#                   UC       UC_count  Manual_Uc_Status
# count  268634.000000  268634.000000     268634.000000
# mean       21.707896       7.344082          0.223360
# std        32.768330       4.753609          0.416498
# min         0.000000       0.000000          0.000000
# 25%        11.000000       4.000000          0.000000
# 50%        16.000000       5.000000          0.000000
# 75%        21.000000      10.000000          0.000000
# max       257.000000      23.000000          1.000000

# %%
plt.figure(figsize=(20,10))
plt.plot(data)
# Out:
# [<matplotlib.lines.Line2D at 0x2397e61dd48>,
#  <matplotlib.lines.Line2D at 0x239218e3b08>,
#  <matplotlib.lines.Line2D at 0x239218e3cc8>,
#  <matplotlib.lines.Line2D at 0x239218e3e88>,
#  <matplotlib.lines.Line2D at 0x23921897148>,
#  <matplotlib.lines.Line2D at 0x23921897388>,
#  <matplotlib.lines.Line2D at 0x23921897548>,
#  <matplotlib.lines.Line2D at 0x23921897788>]

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC']
# MuS = data['Manual_Uc_Status']
plt.plot(uc)



plt.figure(figsize=(25,16))
new = data.copy()
# uc = data['UC']
MuS = data['Manual_Uc_Status']
plt.plot(MuS)

# %%
sns.relplot(
    data=data,
    x="index", y="UC", hue="Manual_Uc_Status"
)

# %%
sns.pairplot(data[['index','ch1','ch2','ch3','dopp','UC','UC_count','Manual_Uc_Status']])

# %%
x = data['index']
z = data['UC']
#----------------------------------------------
plt.figure(figsize=(22,15))
plt.title('UC Vs index', fontsize=14)
plt.xlabel('index', fontsize=14)
plt.ylabel('UC', fontsize=14)
#----------------------------------------------
i = plt.plot(x, z, 'c')
plt.show(i)

# %%
x = data['index']
y = data['UC']
z = data['UC_count']
#----------------------------------------------
plt.figure(figsize=(22,15))
plt.title('UC, Uc_count Vs index', fontsize=14)
plt.xlabel('index', fontsize=14)
plt.ylabel('UC', fontsize=14)
#----------------------------------------------
i = plt.plot(x, y, 'c')
b =plt.plot(x, z, 'y')
plt.show(i,b)

# %%
plt.figure(figsize=(10,8))
plt.title("Ch1")
new = data.copy()
b = data['ch1']
plt.plot(b)

plt.figure(figsize=(10,8))
plt.title("Ch2")
new = data.copy()
c = data['ch2']
plt.plot(c)

plt.figure(figsize=(10,8))
plt.title("Ch3")
new = data.copy()
d = data['ch3']
plt.plot(d)

# %%
plt.figure(figsize=(25,16))
plt.title("dopp")
new = data.copy()
e = data['dopp']
plt.plot(e)
