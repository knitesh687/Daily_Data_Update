# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.reload_library()
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Oct/Oct_29(F)/p2.json'))

# %%
df = data.copy()
del df["raw_data"]["0"]
# data_json["raw_data"]
df = pd.DataFrame(data["raw_data"])

dataf = df.T
data_x = dataf.reset_index()
# data_x = data_x.iloc[:,0]
data_x
file_name = 'p2'
data_x.to_csv(path_or_buf='C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Oct/Oct_29(F)/'+file_name+'.csv')

# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Oct/Oct_29(F)/p2.csv')

# %%
del data['Unnamed: 0']

# %%
data.head()
# Out:
#    index  ch1  ch2  ch3  dopp   UC  UC_count  Manual_Uc_Status
# 0   0.00    0    0  134     0    1         0                 0
# 1   0.40    0    0  137     0    0         0                 0
# 2   0.90    0    0  143     0  102         0                 0
# 3   0.14    0    0  127     0   31         0                 0
# 4   0.21    0    0  138     0  159         0                 0

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182851 entries, 0 to 182850
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             182851 non-null  float64
#  1   ch1               182851 non-null  int64
#  2   ch2               182851 non-null  int64
#  3   ch3               182851 non-null  int64
#  4   dopp              182851 non-null  int64
#  5   UC                182851 non-null  int64
#  6   UC_count          182851 non-null  int64
#  7   Manual_Uc_Status  182851 non-null  int64
# dtypes: float64(1), int64(7)
# memory usage: 11.2 MB
#                index            ch1       ch2            ch3           dopp  \
# count  182851.000000  182851.000000  182851.0  182851.000000  182851.000000
# mean      470.854714      66.099699       0.0     340.728467       8.792749
# std       272.161505      21.711963       0.0     261.029048     122.236520
# min         0.000000       0.000000       0.0       0.000000       0.000000
# 25%       234.936000      69.000000       0.0     106.000000       0.000000
# 50%       470.640000      74.000000       0.0     438.000000       0.000000
# 75%       706.459500      74.000000       0.0     545.000000       0.000000
# max       942.980000     106.000000       0.0    4041.000000    2705.000000
#
#                   UC       UC_count  Manual_Uc_Status
# count  182851.000000  182851.000000     182851.000000
# mean      127.428589       0.526801          0.060251
# std        67.395465       0.499283          0.237952
# min         0.000000       0.000000          0.000000
# 25%        54.000000       0.000000          0.000000
# 50%       137.000000       1.000000          0.000000
# 75%       180.000000       1.000000          0.000000
# max       487.000000       1.000000          1.000000

# %%
plt.figure(figsize=(20,18))
plt.plot(data)
# Out:
# [<matplotlib.lines.Line2D at 0x17cd0401088>,
#  <matplotlib.lines.Line2D at 0x17cd0401288>,
#  <matplotlib.lines.Line2D at 0x17cd0401448>,
#  <matplotlib.lines.Line2D at 0x17cd0401608>,
#  <matplotlib.lines.Line2D at 0x17cd0401808>,
#  <matplotlib.lines.Line2D at 0x17cd0401a08>,
#  <matplotlib.lines.Line2D at 0x17cd0401bc8>,
#  <matplotlib.lines.Line2D at 0x17cd0401dc8>]

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC']
# MuS = data['Manual_Uc_Status']
plt.plot(uc)



plt.figure(figsize=(25,16))
new = data.copy()
# uc = data['UC']
MuS = data['Manual_Uc_Status']
plt.plot(MuS)

# %%
sns.relplot(
    data=data,
    x="index", y="UC", hue="Manual_Uc_Status"
)

# %%
sns.pairplot(data[['index','ch1','ch2','ch3','dopp','UC','UC_count','Manual_Uc_Status']])

# %%
x = data['index']
z = data['UC']
#----------------------------------------------
plt.figure(figsize=(22,15))
plt.title('UC Vs index', fontsize=14)
plt.xlabel('index', fontsize=14)
plt.ylabel('UC', fontsize=14)
#----------------------------------------------
i = plt.plot(x, z, 'c')
plt.show(i)

# %%
x = data['index']
y = data['UC']
z = data['UC_count']
#----------------------------------------------
plt.figure(figsize=(22,15))
plt.title('UC, Uc_count Vs index', fontsize=14)
plt.xlabel('index', fontsize=14)
plt.ylabel('UC', fontsize=14)
#----------------------------------------------
i = plt.plot(x, y, 'c')
b =plt.plot(x, z, 'y')
plt.show(i,b)

# %%
plt.figure(figsize=(10,8))
plt.title("Ch1")
new = data.copy()
b = data['ch1']
plt.plot(b)

plt.figure(figsize=(10,8))
plt.title("Ch2")
new = data.copy()
c = data['ch2']
plt.plot(c)

plt.figure(figsize=(10,8))
plt.title("Ch3")
new = data.copy()
d = data['ch3']
plt.plot(d)

# %%
plt.figure(figsize=(25,16))
plt.title("dopp")
new = data.copy()
e = data['dopp']
plt.plot(e)
