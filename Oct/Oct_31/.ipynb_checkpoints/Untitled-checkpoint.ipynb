# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.reload_library()
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Oct/Oct_31/haritha 31-10-22.json'))

# %%
df = data.copy()
del df["raw_data"]["0"]
# data_json["raw_data"]
df = pd.DataFrame(data["raw_data"])

dataf = df.T
data_x = dataf.reset_index()
# data_x = data_x.iloc[:,0]
data_x
file_name = 'haritha'
data_x.to_csv(path_or_buf='C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Oct/Oct_31/'+file_name+'.csv')

# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Oct/Oct_31/haritha.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  index  ch1  ch2   ch3  dopp   UC  UC_count  Manual_Uc_Status
# 0           0   0.00    0    0  1191     0    0         0                 0
# 1           1   0.40    0    0  1143     0    0         0                 0
# 2           2   0.90    0    0  1099     0    0         0                 0
# 3           3   0.14    0    0  1151     0  149         0                 0
# 4           4   0.19    0    0  1163     0  191         0                 0

# %%
del data['Unnamed: 0']

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445141 entries, 0 to 445140
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             445141 non-null  float64
#  1   ch1               445141 non-null  int64
#  2   ch2               445141 non-null  int64
#  3   ch3               445141 non-null  int64
#  4   dopp              445141 non-null  int64
#  5   UC                445141 non-null  int64
#  6   UC_count          445141 non-null  int64
#  7   Manual_Uc_Status  445141 non-null  int64
# dtypes: float64(1), int64(7)
# memory usage: 27.2 MB
#                index            ch1       ch2            ch3           dopp  \
# count  445141.000000  445141.000000  445141.0  445141.000000  445141.000000
# mean     1113.619485      79.342745       0.0    1345.598622       0.245037
# std       642.934228      29.109794       0.0     681.600873      12.878031
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(data)

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC']
# MuS = data['Manual_Uc_Status']
plt.plot(uc)



plt.figure(figsize=(25,16))
new = data.copy()
# uc = data['UC']
MuS = data['Manual_Uc_Status']
plt.plot(MuS)

# %%
sns.relplot(
    data=data,
    x="index", y="UC", hue="Manual_Uc_Status"
)

# %%
sns.pairplot(data[['index','ch1','ch2','ch3','dopp','UC','UC_count','Manual_Uc_Status']])

# %%
plt.figure(figsize=(10,8))
plt.title("Ch1")
new = data.copy()
# uc = data['UC']
b = data['ch1']
plt.plot(b)

plt.figure(figsize=(10,8))
plt.title("Ch2")
new = data.copy()
c = data['ch2']
# MuS = data['Manual_Uc_Status']
plt.plot(c)

plt.figure(figsize=(10,8))
plt.title("Ch3")
new = data.copy()
# uc = data['UC']
d = data['ch3']
plt.plot(d)

# %%
plt.figure(figsize=(25,16))
plt.title("dopp")
new = data.copy()
e = data['dopp']
# MuS = data['Manual_Uc_Status']
plt.plot(e)

# %%
plt.figure(figsize=(25,16))
plt.title("UC")
new = data.copy()
# uc = data['UC']
f = data['UC']
plt.plot(f)
