# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.reload_library()
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Oct/Oct_31/fowsia 31-10-22.json'))

# %%
df = data.copy()
del df["raw_data"]["0"]
# data_json["raw_data"]
df = pd.DataFrame(data["raw_data"])

dataf = df.T
data_x = dataf.reset_index()
# data_x = data_x.iloc[:,0]
data_x
file_name = 'fowsia'
data_x.to_csv(path_or_buf='C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Oct/Oct_31/'+file_name+'.csv')

# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Oct/Oct_31/fowsia.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  index  ch1  ch2  ch3  dopp   UC  UC_count  Manual_Uc_Status
# 0           0   0.00    0    0  597     0    1         0                 0
# 1           1   0.40    0    0  591     0   64         0                 0
# 2           2   0.11    0    0  553     0   36         0                 0
# 3           3   0.15    0    0  574     0  155         0                 0
# 4           4   0.20    0    0  562     0  123         0                 0

# %%
del data['Unnamed: 0']

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356821 entries, 0 to 356820
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             356821 non-null  float64
#  1   ch1               356821 non-null  int64
#  2   ch2               356821 non-null  int64
#  3   ch3               356821 non-null  int64
#  4   dopp              356821 non-null  int64
#  5   UC                356821 non-null  int64
#  6   UC_count          356821 non-null  int64
#  7   Manual_Uc_Status  356821 non-null  int64
# dtypes: float64(1), int64(7)
# memory usage: 21.8 MB
#                index            ch1       ch2            ch3           dopp  \
# count  356821.000000  356821.000000  356821.0  356821.000000  356821.000000
# mean      892.600697      80.484035       0.0     864.033759       1.431603
# std       515.409771      22.901539       0.0     691.125472      33.201515
# min         0.000000       0.000000       0.0       0.000000       0.000000
# 25%       446.240000      73.000000       0.0     223.000000       0.000000
# 50%       892.574000      85.000000       0.0     752.000000       0.000000
# 75%      1338.916000      94.000000       0.0    1393.000000       0.000000
# max      1785.950000     112.000000       0.0    3209.000000    2571.000000
#
#                   UC       UC_count  Manual_Uc_Status
# count  356821.000000  356821.000000     356821.000000
# mean       71.707405     236.313816          0.183403
# std        57.021626     117.584029          0.386997
# min         0.000000       0.000000          0.000000
# 25%        19.000000     158.000000          0.000000
# 50%        63.000000     239.000000          0.000000
# 75%       116.000000     327.000000          0.000000
# max       257.000000     417.000000          1.000000

# %%
plt.figure(figsize=(20,10))
plt.plot(data)
# Out:
# [<matplotlib.lines.Line2D at 0x232174f0f48>,
#  <matplotlib.lines.Line2D at 0x232174da308>,
#  <matplotlib.lines.Line2D at 0x232174da4c8>,
#  <matplotlib.lines.Line2D at 0x232174da688>,
#  <matplotlib.lines.Line2D at 0x232174da908>,
#  <matplotlib.lines.Line2D at 0x232174dab48>,
#  <matplotlib.lines.Line2D at 0x232174dad08>,
#  <matplotlib.lines.Line2D at 0x232174daf88>]

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC']
# MuS = data['Manual_Uc_Status']
plt.plot(uc)



plt.figure(figsize=(25,16))
new = data.copy()
# uc = data['UC']
MuS = data['Manual_Uc_Status']
plt.plot(MuS)

# %%
sns.relplot(
    data=data,
    x="index", y="UC", hue="Manual_Uc_Status"
)

# %%
sns.pairplot(data[['index','ch1','ch2','ch3','dopp','UC','UC_count','Manual_Uc_Status']])

# %%
plt.figure(figsize=(10,8))
plt.title("Ch1")
new = data.copy()
# uc = data['UC']
b = data['ch1']
plt.plot(b)

plt.figure(figsize=(10,8))
plt.title("Ch2")
new = data.copy()
c = data['ch2']
# MuS = data['Manual_Uc_Status']
plt.plot(c)

plt.figure(figsize=(10,8))
plt.title("Ch3")
new = data.copy()
# uc = data['UC']
d = data['ch3']
plt.plot(d)

# %%
plt.figure(figsize=(25,16))
plt.title("dopp")
new = data.copy()
e = data['dopp']
# MuS = data['Manual_Uc_Status']
plt.plot(e)

# %%
plt.figure(figsize=(25,16))
plt.title("UC")
new = data.copy()
# uc = data['UC']
f = data['UC']
plt.plot(f)
