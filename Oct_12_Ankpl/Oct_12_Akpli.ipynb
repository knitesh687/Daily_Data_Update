# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.reload_library()
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Oct/Oct_12/p1.csv')
del data['Unnamed: 0']

# %%
data.head()
# Out:
#    index  ch1  ch2  ch3  dopp  UC  UC_count  Manual_Uc_Status
# 0   0.00    0    0  686     0   1         0                 0
# 1   0.40    0    0  660     0   0         0                 0
# 2   0.90    0    0  640     0   6         0                 0
# 3   0.14    0    0  615     0   0         0                 0
# 4   0.19    0    0  591     0   0         0                 0

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168067 entries, 0 to 168066
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             168067 non-null  float64
#  1   ch1               168067 non-null  int64
#  2   ch2               168067 non-null  int64
#  3   ch3               168067 non-null  int64
#  4   dopp              168067 non-null  int64
#  5   UC                168067 non-null  int64
#  6   UC_count          168067 non-null  int64
#  7   Manual_Uc_Status  168067 non-null  int64
# dtypes: float64(1), int64(7)
# memory usage: 10.3 MB
#                index       ch1       ch2            ch3      dopp  \
# count  168067.000000  168067.0  168067.0  168067.000000  168067.0
# mean      314.670176       0.0       0.0    1213.533983       0.0
# std       223.697462       0.0       0.0    1399.933265       0.0
# min         0.000000       0.0       0.0       0.000000       0.0
# ...

# %% [markdown]
# # Overall Dataset

# %%
plt.figure(figsize=(20,16))
plt.plot(data)

# %% [markdown]
# # Relationship Between UC & Manual Uc_Status.

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC']
plt.plot(uc)
#-----------------------------------------
plt.figure(figsize=(25,16))
new = data.copy()
MuS = data['Manual_Uc_Status']
plt.plot(MuS)

# %% [markdown]
# # Relation b/w "index, UC, and Manual_Uc_Status"

# %%
sns.relplot(
    data=data,
    x="index", y="UC", hue="Manual_Uc_Status"
)

# %% [markdown]
# # Relation b/w 'index', 'UC', 'UC_count', 'Manual_Uc_Status'

# %%
sns.pairplot(data[['index', 'UC','UC_count', 'Manual_Uc_Status']])

# %% [markdown]
# # Relation b/w UC, UC_count and index

# %%
x = data['index']
y = data['UC']
z = data['UC_count']
#----------------------------------------------
plt.figure(figsize=(22,15))
plt.title('UC, Uc_count Vs index', fontsize=14)
plt.xlabel('index', fontsize=14)
plt.ylabel('UC', fontsize=14)
#----------------------------------------------
i = plt.plot(x, y, 'c')
b =plt.plot(x, z, 'y')
plt.show(i,b)

# %% [markdown]
# # Relation b/w UC and index

# %%
x = data['index']
y = data['UC']
#----------------------------------------------
plt.figure(figsize=(20,15))
plt.title('UC Vs index', fontsize=14)
plt.xlabel('index', fontsize=14)
plt.ylabel('UC', fontsize=14)
#----------------------------------------------
i = plt.plot(x, y, 'c')
plt.show(b)

# %% [markdown]
# # Relation b/w UC_count and index

# %%
x = data['index']
z = data['UC_count']
#----------------------------------------------
plt.figure(figsize=(22,15))
plt.title('UC Vs index', fontsize=14)
plt.xlabel('index', fontsize=14)
plt.ylabel('UC', fontsize=14)
#----------------------------------------------
i = plt.plot(x, z, 'c')
plt.show(i)
