# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.reload_library()
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_22_Testt/1.json'))

# %%
df = data.copy()
# del df["raw_data"]["0"]
# data_json["raw_data"]
df = pd.DataFrame(data["raw_data"])

dataf = df.T
data_x = dataf.reset_index()
# data_x = data_x.iloc[:,0]
data_x
file_name = '1'
data_x.to_csv(path_or_buf='C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_22_Testt/'+file_name+'.csv')

# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_22_Testt/1.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  index  ch1  ch2    ch3  dopp   UC  UC_count  Manual_Uc_Status
# 0           0  0.100    0    0   29.0     0   -1         0                 0
# 1           1  0.500    0    0   37.0     0  118         0                 0
# 2           2  0.100    0    0   45.0     0  271         0                 0
# 3           3  0.193    0    0  193.0     0  301         1                 0
# 4           4  0.197    0    0  355.0     0  253         1                 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16030 entries, 0 to 16029
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        16030 non-null  int64
#  1   index             16030 non-null  float64
#  2   ch1               16030 non-null  int64
#  3   ch2               16030 non-null  int64
#  4   ch3               16030 non-null  float64
#  5   dopp              16030 non-null  int64
#  6   UC                16030 non-null  int64
#  7   UC_count          16030 non-null  int64
#  8   Manual_Uc_Status  16030 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 1.1 MB

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC']
# MuS = data['Manual_Uc_Status']
plt.plot(uc)



plt.figure(figsize=(25,16))
new = data.copy()
# uc = data['UC']
MuS = data['Manual_Uc_Status']
plt.plot(MuS)

# %%
plt.rcParams["figure.figsize"] = [20,16]
plt.rcParams["figure.autolayout"] = True
plt.plot(data['UC'])
# plt.plot(data['Manual_Uc_Status'])
plt.plot(data['UC_count'])
# plt.plot(data['index'])
# plt.plot(data['dopp'])
#display plot
plt.show()

# %%
sns.set(rc = {'figure.figsize':(20,10)})
sns.relplot(
    data=data,
    x="index", y="UC", hue="Manual_Uc_Status",height=9, aspect=15/10

)
