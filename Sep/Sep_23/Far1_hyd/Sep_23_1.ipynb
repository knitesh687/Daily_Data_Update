# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.reload_library()
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/1.json'))
data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/2.json'))
data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/3.json'))
# data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/4.json'))
# data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/5.json'))
# data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/6.json'))
# data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/7.json'))
# data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/8.json'))
# data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/9.json'))
# data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/10.json'))
# data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/11.json'))

# %%
data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/1.json'))

df = data.copy()
del df["raw_data"]["0"]
# data_json["raw_data"]
df = pd.DataFrame(data["raw_data"])

dataf = df.T
data_x = dataf.reset_index()
# data_x = data_x.iloc[:,0]
data_x
file_name = '1'
data_x.to_csv(path_or_buf='C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/'+file_name+'.csv')


data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/1.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  index  ch1  ch2  ch3  dopp  UC  UC_count  Manual_Uc_Status
# 0           0   0.10    0    0  0.0     0  -1         0                -1
# 1           1   0.50    0    0  0.0     0  -1         0                -1
# 2           2   0.13    0    0  0.0     0  -1         0                -1
# 3           3   0.18    0    0  0.0     0  -1         0                -1
# 4           4   0.23    0    0  0.0     0  -1         0                -1

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23051 entries, 0 to 23050
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        23051 non-null  int64
#  1   index             23051 non-null  float64
#  2   ch1               23051 non-null  int64
#  3   ch2               23051 non-null  int64
#  4   ch3               23051 non-null  float64
#  5   dopp              23051 non-null  int64
#  6   UC                23051 non-null  int64
#  7   UC_count          23051 non-null  int64
#  8   Manual_Uc_Status  23051 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 1.6 MB
#          Unnamed: 0         index           ch1      ch2          ch3  \
# count  23051.000000  23051.000000  23051.000000  23051.0  23051.00000
# mean   11525.000000     58.774872     59.329400      0.0     28.62609
# std     6654.394864     33.889068     21.025044      0.0    115.55373
# ...

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC']
# MuS = data['Manual_Uc_Status']
plt.plot(uc)



plt.figure(figsize=(25,16))
new = data.copy()
# uc = data['UC']
MuS = data['Manual_Uc_Status']
plt.plot(MuS)

# %%
sns.relplot(
    data=data,
    x="index", y="UC", hue="Manual_Uc_Status"
)

# %%
sns.pairplot(data[['index', 'UC','UC_count', 'Manual_Uc_Status']])

# %%
plt.rcParams["figure.figsize"] = [20,16]
plt.rcParams["figure.autolayout"] = True
plt.plot(data['UC'].iloc[0:5000])
plt.plot(data['Manual_Uc_Status'].iloc[0:5000])
plt.plot(data['UC_count'].iloc[0:5000])
# plt.plot(data['index'])
# plt.plot(data['dopp'])
#display plot
plt.show()

# %%
plt.rcParams["figure.figsize"] = [20,16]
plt.rcParams["figure.autolayout"] = True
plt.plot(data['UC'].iloc[0:1000])
plt.plot(data['Manual_Uc_Status'].iloc[0:1000])
plt.plot(data['UC_count'].iloc[0:1000])

# %% [markdown]
# # Second Dataset

# %%
data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/2.json'))

df = data.copy()
del df["raw_data"]["0"]
# data_json["raw_data"]
df = pd.DataFrame(data["raw_data"])

dataf = df.T
data_x = dataf.reset_index()
# data_x = data_x.iloc[:,0]
data_x
file_name = '2'
data_x.to_csv(path_or_buf='C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/'+file_name+'.csv')

# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/2.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  index  ch1  ch2  ch3  dopp  UC  UC_count  Manual_Uc_Status
# 0           0   0.10    0    0  0.0     0  -1         0                -1
# 1           1   0.50    0    0  0.0     0  -1         0                -1
# 2           2   0.10    0    0  0.0     0  -1         0                -1
# 3           3   0.15    0    0  0.0     0  -1         0                -1
# 4           4   0.20    0    0  0.0     0  -1         0                -1

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138786 entries, 0 to 138785
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        138786 non-null  int64
#  1   index             138786 non-null  float64
#  2   ch1               138786 non-null  int64
#  3   ch2               138786 non-null  int64
#  4   ch3               138786 non-null  float64
#  5   dopp              138786 non-null  int64
#  6   UC                138786 non-null  int64
#  7   UC_count          138786 non-null  int64
#  8   Manual_Uc_Status  138786 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 9.5 MB
#           Unnamed: 0          index            ch1       ch2            ch3  \
# count  138786.000000  138786.000000  138786.000000  138786.0  138786.000000
# mean    69392.500000     357.161211      70.190091       0.0      75.007256
# ...

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC']
# MuS = data['Manual_Uc_Status']
plt.plot(uc)



plt.figure(figsize=(25,16))
new = data.copy()
# uc = data['UC']
MuS = data['Manual_Uc_Status']
plt.plot(MuS)

# %%
sns.relplot(
    data=data,
    x="index", y="UC", hue="Manual_Uc_Status"
)

# %%
sns.pairplot(data[['index', 'UC','UC_count', 'Manual_Uc_Status']])

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC'].iloc[15000:25000]
# MuS = data['Manual_Uc_Status']
plt.plot(uc)



plt.figure(figsize=(25,16))
new = data.copy()
# uc = data['UC']
MuS = data['Manual_Uc_Status'].iloc[15000:25000]
plt.plot(MuS)

# %%
data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/3.json'))

df = data.copy()
del df["raw_data"]["0"]
# data_json["raw_data"]
df = pd.DataFrame(data["raw_data"])

dataf = df.T
data_x = dataf.reset_index()
# data_x = data_x.iloc[:,0]
data_x
file_name = '3'
data_x.to_csv(path_or_buf='C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/'+file_name+'.csv')


data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/3.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  index  ch1  ch2  ch3  dopp  UC  UC_count  Manual_Uc_Status
# 0           0   0.10    0    0  0.0     0  -1         0                -1
# 1           1   0.50    0    0  0.0     0  -1         0                -1
# 2           2   0.10    0    0  0.0     0  -1         0                -1
# 3           3   0.15    0    0  0.0     0  -1         0                -1
# 4           4   0.20    0    0  0.0     0  -1         0                -1

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138786 entries, 0 to 138785
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        138786 non-null  int64
#  1   index             138786 non-null  float64
#  2   ch1               138786 non-null  int64
#  3   ch2               138786 non-null  int64
#  4   ch3               138786 non-null  float64
#  5   dopp              138786 non-null  int64
#  6   UC                138786 non-null  int64
#  7   UC_count          138786 non-null  int64
#  8   Manual_Uc_Status  138786 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 9.5 MB
#           Unnamed: 0          index            ch1       ch2            ch3  \
# count  138786.000000  138786.000000  138786.000000  138786.0  138786.000000
# mean    69392.500000     357.161211      70.190091       0.0      75.007256
# ...
