# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.reload_library()
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/4.json'))

# %%
df = data.copy()
del df["raw_data"]["0"]
# data_json["raw_data"]
df = pd.DataFrame(data["raw_data"])

dataf = df.T
data_x = dataf.reset_index()
# data_x = data_x.iloc[:,0]
data_x
file_name = '4'
data_x.to_csv(path_or_buf='C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/'+file_name+'.csv')

# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/4.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  index  ch1  ch2  ch3  dopp   UC  UC_count  Manual_Uc_Status
# 0           0   0.00    0    0   20     0   -1         0                -1
# 1           1   0.40    0    0   29     0  255         0                -1
# 2           2   0.90    0    0   23     0  255         0                -1
# 3           3   0.14    0    0   29     0  127         0                -1
# 4           4   0.19    0    0   32     0   85         0                -1

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154091 entries, 0 to 154090
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        154091 non-null  int64
#  1   index             154091 non-null  float64
#  2   ch1               154091 non-null  int64
#  3   ch2               154091 non-null  int64
#  4   ch3               154091 non-null  int64
#  5   dopp              154091 non-null  int64
#  6   UC                154091 non-null  int64
#  7   UC_count          154091 non-null  int64
#  8   Manual_Uc_Status  154091 non-null  int64
# dtypes: float64(1), int64(8)
# memory usage: 10.6 MB
#           Unnamed: 0          index            ch1       ch2            ch3  \
# count  154091.000000  154091.000000  154091.000000  154091.0  154091.000000
# mean    77045.000000     395.502894      64.575712       0.0     103.479444
# std     44482.384502     228.303995      18.332400       0.0     262.487990
# min         0.000000       0.000000       0.000000       0.0       0.000000
# 25%     38522.500000     197.811500      66.000000       0.0       0.000000
# 50%     77045.000000     395.439000      66.000000       0.0       1.000000
# 75%    115567.500000     593.160000      68.000000       0.0     112.000000
# max    154090.000000     791.970000      91.000000       0.0    4066.000000
#
#            dopp             UC       UC_count  Manual_Uc_Status
# count  154091.0  154091.000000  154091.000000     154091.000000
# mean        0.0      19.486401      27.120435         -0.952833
# std         0.0      39.277328       7.365220          0.303496
# min         0.0     -47.000000       0.000000         -1.000000
# 25%         0.0       0.000000      25.000000         -1.000000
# 50%         0.0       0.000000      27.000000         -1.000000
# 75%         0.0      21.000000      32.000000         -1.000000
# max         0.0     382.000000      36.000000          1.000000

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC']
# MuS = data['Manual_Uc_Status']
plt.plot(uc)



plt.figure(figsize=(25,16))
new = data.copy()
# uc = data['UC']
MuS = data['Manual_Uc_Status']
plt.plot(MuS)

# %%
sns.relplot(
    data=data,
    x="index", y="UC", hue="Manual_Uc_Status"
)

# %%
sns.pairplot(data[['index', 'UC','UC_count', 'Manual_Uc_Status']])

# %%
plt.rcParams["figure.figsize"] = [20,16]
plt.rcParams["figure.autolayout"] = True
plt.plot(data['UC'])
plt.plot(data['Manual_Uc_Status'])
plt.plot(data['UC_count'])
# plt.plot(data['index'])
# plt.plot(data['dopp'])
#display plot
plt.show()

# %%
plt.rcParams["figure.figsize"] = [20,16]
plt.rcParams["figure.autolayout"] = True
plt.plot(data['UC'].iloc[0:1000])
plt.plot(data['Manual_Uc_Status'].iloc[0:1000])
plt.plot(data['UC_count'].iloc[0:1000])

# %%
plt.figure(figsize=(25,16))
x1= data['UC'].iloc[0:10000]
# x2 = data['UC'].iloc[14464:28928]
# x3 = data['UC'].iloc[28928:43392]
# x4 = data['UC'].iloc[43392:57856]

plt.plot(x1, 'b')
# plt.plot(x2, 'y')
# plt.plot(x3, 'r')
# plt.plot(x4, 'b')
