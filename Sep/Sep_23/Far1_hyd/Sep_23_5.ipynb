# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.reload_library()
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/5.json'))

# %%
df = data.copy()
del df["raw_data"]["0"]
# data_json["raw_data"]
df = pd.DataFrame(data["raw_data"])

dataf = df.T
data_x = dataf.reset_index()
# data_x = data_x.iloc[:,0]
data_x
file_name = '5'
data_x.to_csv(path_or_buf='C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/'+file_name+'.csv')

# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_23/Far1_hyd/5.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  index  ch1  ch2  ch3  dopp  UC  UC_count  Manual_Uc_Status
# 0           0   0.00    0    0  0.0     0  -1         0                -1
# 1           1   0.40    0    0  0.0     0  -1         0                -1
# 2           2   0.12    0    0  0.0     0  -1         0                -1
# 3           3   0.16    0    0  0.0     0  -1         0                -1
# 4           4   0.20    0    0  0.0     0  -1         0                -1

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132650 entries, 0 to 132649
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        132650 non-null  int64
#  1   index             132650 non-null  float64
#  2   ch1               132650 non-null  int64
#  3   ch2               132650 non-null  int64
#  4   ch3               132650 non-null  float64
#  5   dopp              132650 non-null  int64
#  6   UC                132650 non-null  int64
#  7   UC_count          132650 non-null  int64
#  8   Manual_Uc_Status  132650 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 9.1 MB
#           Unnamed: 0          index            ch1       ch2            ch3  \
# count  132650.000000  132650.000000  132650.000000  132650.0  132650.000000
# mean    66324.500000     343.023368      55.495597       0.0     125.022985
# ...

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC']
# MuS = data['Manual_Uc_Status']
plt.plot(uc)



plt.figure(figsize=(25,16))
new = data.copy()
# uc = data['UC']
MuS = data['Manual_Uc_Status']
plt.plot(MuS)

# %%
sns.relplot(
    data=data,
    x="index", y="UC", hue="Manual_Uc_Status"
)

# %%
sns.pairplot(data[['index', 'UC','UC_count', 'Manual_Uc_Status']])

# %%
plt.rcParams["figure.figsize"] = [20,16]
plt.rcParams["figure.autolayout"] = True
plt.plot(data['UC'])
plt.plot(data['Manual_Uc_Status'])
plt.plot(data['UC_count'])
# plt.plot(data['index'])
# plt.plot(data['dopp'])
#display plot
plt.show()

# %%
ax = sns.violinplot(y = 'UC', x = 'Manual_Uc_Status', data = data)
ax.set_ylabel('UC')
ax.set_xlabel('Manual_Uc_Status')
# Out:
# Text(0.5, 0, 'Manual_Uc_Status')

# %%
sns.catplot(
    data=data, x="UC", y="UC_count", hue="Manual_Uc_Status",
     zorder=1
)
#  native_scale=True,

# %%
sns.regplot(
    data=data, x="UC", y="Manual_Uc_Status",
    scatter=False, truncate=False, order=2, color=".2",
)

# %%
sns.lineplot(data= data, x="UC", y="dopp",hue="Manual_Uc_Status", style="event")

# %%
sns.lmplot(
    data=data, x="index", y="UC", col="UC", hue="Manual_Uc_Status",
    col_wrap=2, palette="muted", ci=None,
    height=4, scatter_kws={"s": 50, "alpha": 1}
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-717be29b1631> in <module>
#       2     data=data, x="index", y="UC_count", col="UC", hue="Manual_Uc_Status",
#       3     col_wrap=2, palette="muted", ci=None,
# ----> 4     height=4, scatter_kws={"s": 50, "alpha": 1}
#       5 )
#
# G:\Anaconda\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     615         scatter_kws=scatter_kws, line_kws=line_kws,
#     616         )
# --> 617     facets.map_dataframe(regplot, x, y, **regplot_kws)
#     618
#     619     # Add a legend
#
# ...

# %%
sns.pairplot(data, hue="Manual_Uc_Status")

# %%
del data['Unnamed: 0']
