# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.reload_library()
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_28/p1.json'))

# %%
df = data.copy()
del df["raw_data"]["0"]
# data_json["raw_data"]
df = pd.DataFrame(data["raw_data"])

dataf = df.T
data_x = dataf.reset_index()
# data_x = data_x.iloc[:,0]
data_x
file_name = 'p1'
data_x.to_csv(path_or_buf='C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_28/'+file_name+'.csv')

# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_28/p1.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  index  ch1  ch2     ch3  dopp   UC  UC_count  Manual_Uc_Status
# 0           0   0.10    0    0  1045.0     0   -1         0                 0
# 1           1   0.40    0    0  1047.0     0  510         0                 0
# 2           2   0.90    0    0  1045.0     0  340         0                 0
# 3           3   0.14    0    0  1040.0     0    0         0                 0
# 4           4   0.20    0    0  1015.0     0    8         0                 0

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140581 entries, 0 to 140580
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        140581 non-null  int64
#  1   index             140581 non-null  float64
#  2   ch1               140581 non-null  int64
#  3   ch2               140581 non-null  int64
#  4   ch3               140581 non-null  float64
#  5   dopp              140581 non-null  int64
#  6   UC                140581 non-null  int64
#  7   UC_count          140581 non-null  int64
#  8   Manual_Uc_Status  140581 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 9.7 MB
#           Unnamed: 0          index       ch1       ch2            ch3  \
# count  140581.000000  140581.000000  140581.0  140581.0  140581.000000
# mean    70290.000000     351.520249       0.0       0.0     983.288176
# std     40582.383434     202.923692       0.0       0.0     973.622686
# ...

# %%
del data['Unnamed: 0']

# %%
data.head()
# Out:
#    index  ch1  ch2     ch3  dopp   UC  UC_count  Manual_Uc_Status
# 0   0.10    0    0  1045.0     0   -1         0                 0
# 1   0.40    0    0  1047.0     0  510         0                 0
# 2   0.90    0    0  1045.0     0  340         0                 0
# 3   0.14    0    0  1040.0     0    0         0                 0
# 4   0.20    0    0  1015.0     0    8         0                 0

# %% [markdown]
# # Overall data

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC']
# MuS = data['Manual_Uc_Status']
plt.plot(uc)



plt.figure(figsize=(25,16))
new = data.copy()
# uc = data['UC']
MuS = data['Manual_Uc_Status']
plt.plot(MuS)

# %% [markdown]
# # Below data are Manual UC Status = 1

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC'].iloc[106300:127000]
uc1 = data['UC'].iloc[16800:23700]
uc2 = data['UC'].iloc[41000:51000]
uc3 = data['UC'].iloc[62500:73150]
uc4 = data['UC'].iloc[87900:94900]
uc5 = data['UC'].iloc[106300:127000]
# MuS = data['Manual_Uc_Status']
plt.plot(uc)
plt.plot(uc1)
plt.plot(uc2)
plt.plot(uc3)
plt.plot(uc4)
plt.plot(uc5)


plt.figure(figsize=(25,16))
new = data.copy()
# uc = data['UC']
Muc = data['Manual_Uc_Status'].iloc[106300:127000]
Muc1 = data['Manual_Uc_Status'].iloc[16800:23700]
Muc2 = data['Manual_Uc_Status'].iloc[41000:51000]
Muc3 = data['Manual_Uc_Status'].iloc[62500:73150]
Muc4 = data['Manual_Uc_Status'].iloc[87900:94900]
Muc5 = data['Manual_Uc_Status'].iloc[106300:127000]
plt.plot(Muc)
plt.plot(Muc1)
plt.plot(Muc2)
plt.plot(Muc3)
plt.plot(Muc4)
plt.plot(Muc5)

# %%
sns.relplot(
    data=data,
    x="index", y="UC", hue="Manual_Uc_Status"
)

# %% [markdown]
# # Compare Data Between "index', 'UC','UC_count', 'Manual_Uc_Status'

# %%
sns.pairplot(data[['index', 'UC','UC_count', 'Manual_Uc_Status']])

# %% [markdown]
# # Second Dataset "Same Patient"

# %%
data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_28/p1_2.json'))

# %%
df = data.copy()
del df["raw_data"]["0"]
# data_json["raw_data"]
df = pd.DataFrame(data["raw_data"])

dataf = df.T
data_x = dataf.reset_index()
# data_x = data_x.iloc[:,0]
data_x
file_name = 'p1_2'
data_x.to_csv(path_or_buf='C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_28/'+file_name+'.csv')

# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_28/p1_2.csv')

# %%
data.head()

# %%
del data['Unnamed: 0']

# %%
data.info()
data.describe()

# %% [markdown]
# # Overall Dataset

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC']
# MuS = data['Manual_Uc_Status']
plt.plot(uc)



plt.figure(figsize=(25,16))
new = data.copy()
# uc = data['UC']
MuS = data['Manual_Uc_Status']
plt.plot(MuS)

# %% [markdown]
# # Below data are Manual UC Status = 1

# %%
plt.figure(figsize=(25,16))
# new = data.copy()
uc = data['UC'].iloc[0:4000]
uc1 = data['UC'].iloc[4850:14500]
uc2 = data['UC'].iloc[16100:27800]
uc3 = data['UC'].iloc[36200:47500]
uc4 = data['UC'].iloc[71200:83100]
uc5 = data['UC'].iloc[93750:109700]
uc6 = data['UC'].iloc[123000:134200]
uc7 = data['UC'].iloc[142650:150250]
uc8 = data['UC'].iloc[195800:215950]
uc9 = data['UC'].iloc[226700:239590]

plt.plot(uc)
plt.plot(uc1)
plt.plot(uc2)
plt.plot(uc3)
plt.plot(uc4)
plt.plot(uc5)
plt.plot(uc6)
plt.plot(uc7)
plt.plot(uc8)
plt.plot(uc9)

plt.figure(figsize=(25,16))
# new = data.copy()
MuS = data['Manual_Uc_Status'].iloc[0:4000]
MuS1 = data['Manual_Uc_Status'].iloc[4850:14500]
MuS2 = data['Manual_Uc_Status'].iloc[16100:27800]
MuS3 = data['Manual_Uc_Status'].iloc[36200:47500]
MuS4 = data['Manual_Uc_Status'].iloc[71200:83100]
MuS5 = data['Manual_Uc_Status'].iloc[93750:109700]
MuS6 = data['Manual_Uc_Status'].iloc[123000:134200]
MuS7 = data['Manual_Uc_Status'].iloc[142650:150250]
MuS8 = data['Manual_Uc_Status'].iloc[195800:215950]
MuS9 = data['Manual_Uc_Status'].iloc[226700:239590]
[260000:275000]

plt.plot(MuS)
plt.plot(MuS1)
plt.plot(MuS2)
plt.plot(MuS3)
plt.plot(MuS4)
plt.plot(MuS5)
plt.plot(MuS6)
plt.plot(MuS7)
plt.plot(MuS8)
plt.plot(MuS9)

# %%
sns.relplot(
    data=data,
    x="index", y="UC", hue="Manual_Uc_Status"
)

# %% [markdown]
# # Compare Data Between "index', 'UC','UC_count', 'Manual_Uc_Status'

# %%
sns.pairplot(data[['index', 'UC','UC_count', 'Manual_Uc_Status']])
