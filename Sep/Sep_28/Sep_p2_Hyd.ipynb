# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.reload_library()
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_28/p2_1_Hyd.json'))

# %%
df = data.copy()
del df["raw_data"]["0"]
# data_json["raw_data"]
df = pd.DataFrame(data["raw_data"])

dataf = df.T
data_x = dataf.reset_index()
# data_x = data_x.iloc[:,0]
data_x
file_name = 'p2_1_Hyd'
data_x.to_csv(path_or_buf='C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_28/'+file_name+'.csv')

# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_28/p2_1_Hyd.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  index  ch1  ch2    ch3  dopp  UC  UC_count  Manual_Uc_Status
# 0           0   0.00    0    0  114.0     0  -1         0                 0
# 1           1   0.40    0    0  113.0     0  85         0                 0
# 2           2   0.90    0    0  108.0     0   0         0                 0
# 3           3   0.14    0    0  112.0   656  36         0                 0
# 4           4   0.20    0    0    0.0     0  -1         0                 0

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318612 entries, 0 to 318611
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        318612 non-null  int64
#  1   index             318612 non-null  float64
#  2   ch1               318612 non-null  int64
#  3   ch2               318612 non-null  int64
#  4   ch3               318612 non-null  float64
#  5   dopp              318612 non-null  int64
#  6   UC                318612 non-null  int64
#  7   UC_count          318612 non-null  int64
#  8   Manual_Uc_Status  318612 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 21.9 MB
#           Unnamed: 0          index            ch1       ch2            ch3  \
# count  318612.000000  318612.000000  318612.000000  318612.0  318612.000000
# mean   159305.500000     427.573029      73.715036       0.0     105.646382
# ...

# %%
del data['Unnamed: 0']

# %%
data.head()
# Out:
#    index  ch1  ch2    ch3  dopp  UC  UC_count  Manual_Uc_Status
# 0   0.00    0    0  114.0     0  -1         0                 0
# 1   0.40    0    0  113.0     0  85         0                 0
# 2   0.90    0    0  108.0     0   0         0                 0
# 3   0.14    0    0  112.0   656  36         0                 0
# 4   0.20    0    0    0.0     0  -1         0                 0

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC']
# MuS = data['Manual_Uc_Status']
plt.plot(uc)



plt.figure(figsize=(25,16))
new = data.copy()
# uc = data['UC']
MuS = data['Manual_Uc_Status']
plt.plot(MuS)

# %%
plt.figure(figsize=(20,16))
new = data.copy()

uc1 = data['UC'].iloc[16800:23700]
uc2 = data['UC'].iloc[41000:51000]
uc3 = data['UC'].iloc[62500:73150]
uc4 = data['UC'].iloc[87900:94900]
uc5 = data['UC'].iloc[106300:127000]


plt.plot(uc1)
plt.plot(uc2)
plt.plot(uc3)
plt.plot(uc4)
plt.plot(uc5)

# %%
plt.figure(figsize=(25,16))
new = data.copy()

Muc1 = data['Manual_Uc_Status'].iloc[16800:23700]
Muc2 = data['Manual_Uc_Status'].iloc[41000:51000]
Muc3 = data['Manual_Uc_Status'].iloc[62500:73150]
Muc4 = data['Manual_Uc_Status'].iloc[87900:94900]
Muc5 = data['Manual_Uc_Status'].iloc[106300:127000]

plt.plot(Muc1)
plt.plot(Muc2)
plt.plot(Muc3)
plt.plot(Muc4)
plt.plot(Muc5)

# %%
sns.relplot(
    data=data,
    x="index", y="UC", hue="Manual_Uc_Status"
)

# %%
sns.pairplot(data[['index', 'UC','UC_count', 'Manual_Uc_Status']])

# %% [markdown]
# # Second Dataset Same Patient

# %%
data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_28/p2_2_Hyd.json'))

# %%
df = data.copy()
del df["raw_data"]["0"]
# data_json["raw_data"]
df = pd.DataFrame(data["raw_data"])

dataf = df.T
data_x = dataf.reset_index()
# data_x = data_x.iloc[:,0]
data_x
file_name = 'p2_2_Hyd'
data_x.to_csv(path_or_buf='C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_28/'+file_name+'.csv')

# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_28/p2_2_Hyd.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  index  ch1  ch2     ch3  dopp   UC  UC_count  Manual_Uc_Status
# 0           0   0.00    0    0   207.0     0   -1         0                 0
# 1           1   0.50    0    0   211.0     0  153         0                 0
# 2           2   0.12    0    0   208.0     0  102         0                 0
# 3           3   0.19    0    0  3962.0     0   78         0                 0
# 4           4   0.24    0    0  3997.0     0   58         0                 0

# %%
del data['Unnamed: 0']

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276778 entries, 0 to 276777
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             276778 non-null  float64
#  1   ch1               276778 non-null  int64
#  2   ch2               276778 non-null  int64
#  3   ch3               276778 non-null  float64
#  4   dopp              276778 non-null  int64
#  5   UC                276778 non-null  int64
#  6   UC_count          276778 non-null  int64
#  7   Manual_Uc_Status  276778 non-null  int64
# dtypes: float64(2), int64(6)
# memory usage: 16.9 MB
#                index            ch1       ch2            ch3           dopp  \
# count  276778.000000  276778.000000  276778.0  276778.000000  276778.000000
# mean      444.955468      77.986581       0.0     467.901618      26.321362
# std       294.077515      20.742551       0.0    1118.055680     202.464273
# ...

# %% [markdown]
# # Overall Data UC and Manual UC

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC']
plt.title("UC")
plt.plot(uc)



plt.figure(figsize=(25,16))
new = data.copy()
plt.title("Manual_Uc_Status")
MuS = data['Manual_Uc_Status']
plt.plot(MuS)

# %%
sns.jointplot(data['Manual_Uc_Status'], data['UC'])

# %%
plt.figure(figsize=(25,16))
new = data.copy()

uc1 = data['UC'].iloc[5500:8600]
uc2 = data['UC'].iloc[14900:20500]
uc3 = data['UC'].iloc[34600:37750]
uc4 = data['UC'].iloc[63000:67000]
uc5 = data['UC'].iloc[104550:109350]
uc6 = data['UC'].iloc[122750:27800]
uc7 = data['UC'].iloc[142300:148900]
uc8 = data['UC'].iloc[190700:195110]
uc9 = data['UC'].iloc[219800:229400]
plt.plot(uc1)
plt.plot(uc2)
plt.plot(uc3)
plt.plot(uc4)
plt.plot(uc5)
plt.plot(uc6)
plt.plot(uc7)
plt.plot(uc8)
plt.plot(uc9)


plt.figure(figsize=(25,16))
new = data.copy()
Muc1 = data['Manual_Uc_Status'].iloc[5500:8600]
Muc2 = data['Manual_Uc_Status'].iloc[14900:20500]
Muc3 = data['Manual_Uc_Status'].iloc[34600:37750]
Muc4 = data['Manual_Uc_Status'].iloc[63000:67000]
Muc5 = data['Manual_Uc_Status'].iloc[104550:109350]
Muc6 = data['Manual_Uc_Status'].iloc[122750:27800]
Muc7 = data['Manual_Uc_Status'].iloc[142300:148900]
Muc8 = data['Manual_Uc_Status'].iloc[190700:195110]
Muc9 = data['Manual_Uc_Status'].iloc[219800:229400]


plt.plot(Muc1)
plt.plot(Muc2)
plt.plot(Muc3)
plt.plot(Muc4)
plt.plot(Muc5)
plt.plot(Muc6)
plt.plot(Muc7)
plt.plot(Muc8)
plt.plot(Muc9)

# %%
sns.relplot(
    data=data,
    x="index", y="UC", hue="Manual_Uc_Status"
)

# %%
sns.pairplot(data[['index', 'UC','UC_count', 'Manual_Uc_Status']])
