# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.reload_library()
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_29/Sep_29_1_Hyd.json'))

# %%
df = data.copy()
del df["raw_data"]["0"]
# data_json["raw_data"]
df = pd.DataFrame(data["raw_data"])

dataf = df.T
data_x = dataf.reset_index()
# data_x = data_x.iloc[:,0]
data_x
file_name = 'p1_Hyd'
data_x.to_csv(path_or_buf='C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_29/'+file_name+'.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-2eb1dc9c24f8> in <module>
#       2 del df["raw_data"]["0"]
#       3 # data_json["raw_data"]
# ----> 4 df = pd.DataFrame(data["raw_data"])
#       5
#       6 dataf = df.T
#
# G:\Anaconda\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# G:\Anaconda\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# ...

# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_29/p1_Hyd.csv')

# %%
data.head()

# %%
del data['Unnamed: 0']

# %%
data.info()
data.describe()

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC']
plt.plot(uc)



plt.figure(figsize=(25,16))
new = data.copy()

MuS = data['Manual_Uc_Status']
plt.plot(MuS)

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC'].iloc[8589:13155]
uc1 = data['UC'].iloc[22416:25371]
plt.plot(uc)
plt.plot(uc1)

plt.figure(figsize=(25,16))
new = data.copy()
MuS = data['Manual_Uc_Status'].iloc[8589:13155]
MuS1 = data['Manual_Uc_Status'].iloc[22416:25371]
plt.plot(MuS)
plt.plot(MuS1)

# %%
sns.relplot(
    data=data,
    x="index", y="UC", hue="Manual_Uc_Status"
)

# %%
sns.pairplot(data[['index', 'UC','UC_count', 'Manual_Uc_Status']])

# %% [markdown]
# # Second Dataset

# %%
data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_29/Sep_29_2_Hyd.json'))

# %%
df = data.copy()
del df["raw_data"]["0"]
# data_json["raw_data"]
df = pd.DataFrame(data["raw_data"])

dataf = df.T
data_x = dataf.reset_index()
# data_x = data_x.iloc[:,0]
data_x
file_name = 'p2_Hyd'
data_x.to_csv(path_or_buf='C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_29/'+file_name+'.csv')

# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_29/p1_Hyd.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  index  ch1  ch2    ch3  dopp   UC  UC_count  Manual_Uc_Status
# 0           0   0.00    0    0   56.0     0   -1         0                 0
# 1           1   0.50    0    0  122.0     0   85         0                 0
# 2           2   0.11    0    0   50.0     0  255         0                 0
# 3           3   0.15    0    0   51.0     0  340         0                 0
# 4           4   0.20    0    0   49.0     0    0         0                 0

# %%
del data['Unnamed: 0']

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239694 entries, 0 to 239693
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             239694 non-null  float64
#  1   ch1               239694 non-null  int64
#  2   ch2               239694 non-null  int64
#  3   ch3               239694 non-null  float64
#  4   dopp              239694 non-null  int64
#  5   UC                239694 non-null  int64
#  6   UC_count          239694 non-null  int64
#  7   Manual_Uc_Status  239694 non-null  int64
# dtypes: float64(2), int64(6)
# memory usage: 14.6 MB
#                index            ch1       ch2            ch3           dopp  \
# count  239694.000000  239694.000000  239694.0  239694.000000  239694.000000
# mean      521.219861      64.018002       0.0      40.240719      32.492207
# std       340.253065      27.731552       0.0      44.164129     231.994684
# ...

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC']
plt.plot(uc)



plt.figure(figsize=(25,16))
new = data.copy()
MuS = data['Manual_Uc_Status']
plt.plot(MuS)

# %%
plt.figure(figsize=(25,16))
new = data.copy()

MuS = data['Manual_Uc_Status'].iloc[12950:21700]
plt.plot(MuS)

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC'].iloc[30000:35000]
plt.plot(uc)



plt.figure(figsize=(25,16))
new = data.copy()

MuS = data['Manual_Uc_Status'].iloc[30590:35200]
plt.plot(MuS)

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC'].iloc[12950:21700]
uc1 = data['UC'].iloc[30590:35200]
uc2 = data['UC'].iloc[63958:86020]
uc3 = data['UC'].iloc[96964:106819]
uc4 = data['UC'].iloc[121195:128341]
uc5 = data['UC'].iloc[158098:162837]
uc6 = data['UC'].iloc[183634:190897]
uc7 = data['UC'].iloc[206213:212946]
uc8 = data['UC'].iloc[226670:236251]
plt.plot(uc)
plt.plot(uc1)
plt.plot(uc2)
plt.plot(uc3)
plt.plot(uc4)
plt.plot(uc5)
plt.plot(uc6)
plt.plot(uc7)
plt.plot(uc8)




plt.figure(figsize=(25,16))
new = data.copy()

MuS = data['Manual_Uc_Status'].iloc[12950:21700]
MuS1 = data['Manual_Uc_Status'].iloc[30590:35200]
MuS2 = data['Manual_Uc_Status'].iloc[63950:86020]
MuS3 = data['Manual_Uc_Status'].iloc[96954:106819]
MuS4 = data['Manual_Uc_Status'].iloc[121100:128341]
MuS5 = data['Manual_Uc_Status'].iloc[157908:162837]
MuS6 = data['Manual_Uc_Status'].iloc[183534:190897]
MuS7 = data['Manual_Uc_Status'].iloc[206113:212946]
MuS8 = data['Manual_Uc_Status'].iloc[226570:236251]



plt.plot(MuS)
plt.plot(MuS1)
plt.plot(MuS2)
plt.plot(MuS3)
plt.plot(MuS4)
plt.plot(MuS5)
plt.plot(MuS6)
plt.plot(MuS7)
plt.plot(MuS8)

# %%
plt.figure(figsize=(25,16))
new = data.copy()

MuS = data['Manual_Uc_Status'].iloc[12950:21700]
plt.plot(MuS)
