# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.reload_library()
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
data = json.load(open('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_20/20_Sep_1.json'))

# %%
df = data.copy()
del df["raw_data"]["0"]
# data_json["raw_data"]
df = pd.DataFrame(data["raw_data"])

dataf = df.T
data_x = dataf.reset_index()
# data_x = data_x.iloc[:,0]
data_x
file_name = 'p2'
data_x.to_csv(path_or_buf='C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_20/'+file_name+'.csv')

# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Daily_Data_Update/Sep_20/p2.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  index  ch1  ch2  ch3  dopp   UC  UC_count  Manual_Uc_Status
# 0           0   0.00    0    0  392     0   -1         0                -1
# 1           1   0.40    0    0  373     0  300         0                -1
# 2           2   0.12    0    0  397     0  331         0                -1
# 3           3   0.19    0    0  399     0  240         0                -1
# 4           4   0.23    0    0  405     0  270         0                -1

# %%
del data['Unnamed: 0']

# %%
data.describe()
# Out:
#               index      ch1      ch2           ch3     dopp          UC  \
# count  34600.000000  34600.0  34600.0  34600.000000  34600.0  34600.0000
# mean      89.172297      0.0      0.0     89.772486      0.0     22.9500
# std       51.431879      0.0      0.0    182.007742      0.0     45.4355
# min        0.000000      0.0      0.0      0.000000      0.0    -10.0000
# 25%       44.617750      0.0      0.0      0.000000      0.0      0.0000
# 50%       89.260500      0.0      0.0      0.000000      0.0      0.0000
# 75%      133.740250      0.0      0.0    110.000000      0.0     28.0000
# max      178.980000      0.0      0.0   1616.000000      0.0    331.0000
#
#            UC_count  Manual_Uc_Status
# count  34600.000000      34600.000000
# mean       5.684682         -0.195954
# std        3.050799          0.980627
# min        0.000000         -1.000000
# 25%        4.000000         -1.000000
# 50%        5.000000         -1.000000
# 75%        9.000000          1.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34600 entries, 0 to 34599
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             34600 non-null  float64
#  1   ch1               34600 non-null  int64
#  2   ch2               34600 non-null  int64
#  3   ch3               34600 non-null  int64
#  4   dopp              34600 non-null  int64
#  5   UC                34600 non-null  int64
#  6   UC_count          34600 non-null  int64
#  7   Manual_Uc_Status  34600 non-null  int64
# dtypes: float64(1), int64(7)
# memory usage: 2.1 MB

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC']
plt.plot(uc)

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc_count = data['UC_count']
plt.plot(uc_count)

# %%
sns.distplot(data['UC_count'],bins=50)
sns.distplot(data['UC'], kde=False, rug=True);

# %%
sns.distplot(data['UC_count'],bins=50)

# %%
UC = data['UC']
M_UC_count= data['Manual_Uc_Status']
sns.jointplot(UC, M_UC_count)

# %%
sns.pairplot(data[['index', 'UC_count', 'UC', 'Manual_Uc_Status']])

# %%
plt.rcParams["figure.figsize"] = [20,16]
plt.rcParams["figure.autolayout"] = True
plt.plot(data['UC'])
plt.plot(data['Manual_Uc_Status'])
plt.plot(data['UC_count'])
plt.plot(data['index'])
#display plot
plt.show()

# %%
plt.figure(figsize=(25,16))
x1= data['UC'].iloc[0:8650]
x2 = data['UC'].iloc[8650:17300]
x3 = data['UC'].iloc[17300:25950]


plt.plot(x1, 'g')
plt.plot(x2, 'y')
plt.plot(x3, 'r')
