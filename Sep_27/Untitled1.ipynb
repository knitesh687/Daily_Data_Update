# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
plt.style.reload_library()
import matplotlib
# reload(matplotlib)
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Visual/27_Aug_Visual/p1.csv')
data1 = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Visual/27_Aug_Visual/p2.csv')

# %%
data
# Out:
#         Unnamed: 0     index  ch1  ch2  ch3  dopp  UC  UC_count
# 0                0     0.000    0    0    0     0  -1         0
# 1                1     0.400    0    0    0     0  -1         0
# 2                2     0.900    0    0    0     0  -1         0
# 3                3     0.140    0    0    0     0  -1         0
# 4                4     0.190    0    0    0     0  -1         0
# ...            ...       ...  ...  ...  ...   ...  ..       ...
# 485695      485695  2410.506    0    0    0     0   0        29
# 485696      485696  2410.511    0    0    0     0   0        29
# 485697      485697  2410.516    0    0    0     0   0        29
# 485698      485698  2410.521    0    0    0     0   0        29
# 485699      485699  2410.526    0    0    0     0   0        29
#
# [485700 rows x 8 columns]

# %%
data1
# Out:
#         Unnamed: 0     index  ch1  ch2  ch3  dopp  UC  UC_count
# 0                0     0.100    0    0    0     0  -1         0
# 1                1     0.500    0    0    0     0  -1         0
# 2                2     0.100    0    0    0     0  -1         0
# 3                3     0.150    0    0    0     0  -1         0
# 4                4     0.200    0    0    0     0  -1         0
# ...            ...       ...  ...  ...  ...   ...  ..       ...
# 521270      521270  2606.375    0    0   99     0   6        39
# 521271      521271  2606.380    0    0  105     0   6        39
# 521272      521272  2606.385    0    0  103     0   6        39
# 521273      521273  2606.390    0    0  103     0   6        39
# 521274      521274  2606.395    0    0   98     0   6        39
#
# [521275 rows x 8 columns]

# %%
data.shape
# Out:
# (485700, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485700 entries, 0 to 485699
# Data columns (total 5 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   index     485700 non-null  float64
#  1   ch3       485700 non-null  int64
#  2   dopp      485700 non-null  int64
#  3   UC        485700 non-null  int64
#  4   UC_count  485700 non-null  int64
# dtypes: float64(1), int64(4)
# memory usage: 18.5 MB

# %%
data.describe()
# Out:
#           Unnamed: 0          index       ch1       ch2            ch3  \
# count  485700.000000  485700.000000  485700.0  485700.0  485700.000000
# mean   242849.500000    1196.443921       0.0       0.0      39.831981
# std    140209.657209     700.825548       0.0       0.0     364.858752
# min         0.000000       0.000000       0.0       0.0       0.000000
# 25%    121424.750000     589.213750       0.0       0.0       0.000000
# 50%    242849.500000    1196.332500       0.0       0.0       0.000000
# 75%    364274.250000    1803.452250       0.0       0.0       0.000000
# max    485699.000000    2410.960000       0.0       0.0    4049.000000
#
#                 dopp             UC       UC_count
# count  485700.000000  485700.000000  485700.000000
# mean       13.814921       2.426039      14.695897
# std       144.931344      23.157461      10.514494
# min         0.000000      -1.000000       0.000000
# 25%         0.000000       0.000000       5.000000
# ...

# %%
data['ch3']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 485695    0
# 485696    0
# 485697    0
# 485698    0
# 485699    0
# Name: ch3, Length: 485700, dtype: int64

# %%
plt.figure(figsize=(25,16))
x = data.iloc[:,1]
plt.title("Count:0 to 4.8L, Step 5")
plt.plot(y)

# %%
plt.figure(figsize=(25,16))
x = data.copy()
y = data.iloc[:485700,3]
plt.title("Count: 0 to 4.8L, Step 3")
plt.plot(y)

# %%
plt.figure(figsize=(25,16))
y = data.iloc[:485700,4]
plt.title("Count: 0 to 4.8L, Step 4")
plt.plot(y)

# %%
plt.figure(figsize=(25,16))
y = data.iloc[:485700,2]
plt.title("Count: 0 to 4.8L, Step 7")
plt.plot(y)

# %%
del data['ch1']
del data['Unnamed: 0']
del data['ch2']

# %%
data
# Out:
#            index  ch3  dopp  UC  UC_count
# 0          0.000    0     0  -1         0
# 1          0.400    0     0  -1         0
# 2          0.900    0     0  -1         0
# 3          0.140    0     0  -1         0
# 4          0.190    0     0  -1         0
# ...          ...  ...   ...  ..       ...
# 485695  2410.506    0     0   0        29
# 485696  2410.511    0     0   0        29
# 485697  2410.516    0     0   0        29
# 485698  2410.521    0     0   0        29
# 485699  2410.526    0     0   0        29
#
# [485700 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485700 entries, 0 to 485699
# Data columns (total 5 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   index     485700 non-null  float64
#  1   ch3       485700 non-null  int64
#  2   dopp      485700 non-null  int64
#  3   UC        485700 non-null  int64
#  4   UC_count  485700 non-null  int64
# dtypes: float64(1), int64(4)
# memory usage: 18.5 MB

# %%
data.describe()
# Out:
#                index            ch3           dopp             UC  \
# count  485700.000000  485700.000000  485700.000000  485700.000000
# mean     1196.443921      39.831981      13.814921       2.426039
# std       700.825548     364.858752     144.931344      23.157461
# min         0.000000       0.000000       0.000000      -1.000000
# 25%       589.213750       0.000000       0.000000       0.000000
# 50%      1196.332500       0.000000       0.000000       0.000000
# 75%      1803.452250       0.000000       0.000000       0.000000
# max      2410.960000    4049.000000    2639.000000     269.000000
#
#             UC_count
# count  485700.000000
# mean       14.695897
# std        10.514494
# min         0.000000
# 25%         5.000000
# 50%        15.000000
# 75%        27.000000
# max        29.000000

# %%
plt.figure(figsize=(25,16))
x1= data.iloc[0:16190,1]
x2 = data.iloc[16190:32380,1]
x3 = data.iloc[32380:48570,1]
x4 = data.iloc[48570:64760,1]
x5 = data.iloc[64760:80950,1]
plt.plot(x1)
plt.plot(x2, 'y')
plt.plot(x3, 'r')
plt.plot(x4, 'b')
plt.plot(x5, 'o')

# %%
plt.figure(figsize=(25,16))
x = data.iloc[700:1800:1]
x1 = data.iloc[269:2690:1]
plt.plot(x)
plt.plot(x1)

# %%
plt.plot(x1)

# %%
fig = plt.figure(figsize=[20, 8])
x = data['UC'].iloc[1000:80950]
y = data['UC_count'].iloc[1000:80950]
plt.scatter(x, y, s=120)
plt.plot(x, y, color='green', linewidth=2)

# %%
fig = plt.figure(figsize=[20, 8])
y = data['UC'].iloc[:10000]
z = data['UC_count'].iloc[:10000]
x = data['index'].iloc[:10000]
print(x,y,z)
# Out:
# 0        0.000
# 1        0.400
# 2        0.900
# 3        0.140
# 4        0.190
#          ...
# 9995    31.970
# 9996    31.975
# 9997    31.980
# 9998    31.985
# 9999    31.990
# Name: index, Length: 10000, dtype: float64 0      -1
# 1      -1
# 2      -1
# 3      -1
# 4      -1
#        ..
# 9995   -1
# 9996   -1
# 9997   -1
# 9998   -1
# 9999   -1
# Name: UC, Length: 10000, dtype: int64 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: UC_count, Length: 10000, dtype: int64

# %%
data_1 = data['index'].iloc[:]
sns.distplot(data_1,bins=5)

# %%
sns.distplot(data['UC_count'],bins=50)

# %%
sns.distplot(data['index'], kde=False, rug=True);

# %%
sns.distplot(data['UC'], kde=False, rug=True);

# %%
sns.distplot(data['UC_count'], kde=False, rug=True);

# %%
# plt.figure(figsize=(25,16))
print("Count: 0 to 16190, 1 Min ")
index_1 = data['index'].iloc[0:16190]
UC_count_1 = data['UC_count'].iloc[0:16190]
sns.jointplot(index_1, UC_count_1)
# Out:
# Count: 0 to 16190, 1 Min

# %%
print("Count: 0 to 80950, 5 Min ")
index_1 = data['index'].iloc[:80950]
UC_count_1 = data['UC_count'].iloc[0:80950]
sns.jointplot(index_1, UC_count_1)
sns.jointplot(index_1, UC_count_1, kind='hex')
sns.jointplot(index_1, UC_count_1, kind = 'kde')
# Out:
# Count: 0 to 80950, 5 Min

# %%
sns.pairplot(data[['index', 'UC_count', 'UC']])

# %%
sns.pointplot(data['index'], data['UC'], hue=data['UC_count'])

# %%
sns.pointplot(data['UC_count'], data['UC'], hue=data['index'])

# %%
sns.lmplot(x="index", y="UC_count", data=data)

# %%
sns.lmplot(x="horsepower", y="peak_rpm",hue="fuel_type", data=auto)
