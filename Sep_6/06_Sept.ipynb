# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.reload_library()
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/Visual/26_Aug_1.csv')
dj = json.load(open('C:/Users/Acer/Desktop/INDQ/New folder/test_.json'))
dj_1 = json.load(open('C:/Users/Acer/Desktop/INDQ/New folder/test_2.json'))

# %%
data = dj.copy()
del data["raw_data"]["0"]
# data_json["raw_data"]
df = pd.DataFrame(data["raw_data"])

dataf = df.T
data_x = dataf.reset_index()
# data_x = data_x.iloc[:,0]
data_x
file_name = 't1'
data_x.to_csv(path_or_buf='C:/Users/Acer/Desktop/INDQ/New folder/'+file_name+'.csv')

# %%
# data1 = dj_1.copy()
# # del data["raw_data"]["0"]
# # data_json["raw_data"]
# df = pd.DataFrame(data["raw_data"])

# dataf = df.T
# data_x = dataf.reset_index()
# # data_x = data_x.iloc[:,0]
# data_x
# file_name = 't2'
# data_x.to_csv(path_or_buf='C:/Users/Acer/Desktop/INDQ/New folder/'+file_name+'.csv')

# %%
data = pd.read_csv('C:/Users/Acer/Desktop/INDQ/New folder/t1.csv')
data1 = pd.read_csv('C:/Users/Acer/Desktop/INDQ/New folder/t2.csv')

# %%
data
# Out:
# {'device_name': 'JANANYA_2',
#  'raw_data': {'0.0': {'ch1': '0',
#    'ch2': '0',
#    'ch3': '1732.00',
#    'dopp': '0',
#    'UC': '-1',
#    'UC_count': '0',
#    'Manual_Uc_Status': -1},
#   '0.4': {'ch1': '0',
#    'ch2': '0',
#    'ch3': '1718.00',
#    'dopp': '0',
#    'UC': '91',
#    'UC_count': '0',
#    'Manual_Uc_Status': -1},
#   '0.9': {'ch1': '0',
#    'ch2': '0',
#    'ch3': '1703.00',
#    'dopp': '0',
#    'UC': '11',
#    'UC_count': '0',
#    'Manual_Uc_Status': -1},
#   '0.14': {'ch1': '0',
#    'ch2': '0',
#    'ch3': '1741.00',
#    'dopp': '0',
#    'UC': '262',
#    'UC_count': '0',
#    'Manual_Uc_Status': -1},
#   '0.19': {'ch1': '0',
#    'ch2': '0',
#    'ch3': '1731.00',
#    'dopp': '0',
#    'UC': '177',
#    'UC_count': '0',
#    'Manual_Uc_Status': -1},
#   '0.24': {'ch1': '0',
#    'ch2': '0',
#    'ch3': '1712.00',
#    'dopp': '0',
#    'UC': '50',
#    'UC_count': '0',
#    'Manual_Uc_Status': -1},
#   '0.29': {'ch1': '0',
#    'ch2': '0',
# ...

# %%
del data['Unnamed: 0']
del data['ch1']
del data['ch2']
del data['ch3']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-95-bca1b62f71c6> in <module>
# ----> 1 del data['Unnamed: 0']
#       2 del data['ch1']
#       3 del data['ch2']
#       4 del data['ch3']
#
# KeyError: 'Unnamed: 0'

# %%
data

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-96-304fa4ce4ebd> in <module>
# ----> 1 data.head()
#
# AttributeError: 'dict' object has no attribute 'head'

# %%
data.info()

data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25959 entries, 0 to 25958
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             25959 non-null  float64
#  1   dopp              25959 non-null  int64
#  2   UC                25959 non-null  int64
#  3   UC_count          25959 non-null  int64
#  4   Manual_Uc_Status  25959 non-null  object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1014.1+ KB
#               index          dopp            UC      UC_count
# count  25959.000000  25959.000000  25959.000000  25959.000000
# mean      64.958976     69.037983    141.107323     19.230517
# std       37.482870    336.174467     35.657436     11.585641
# min        0.000000      0.000000    -25.000000      0.000000
# 25%       32.503500      0.000000    132.000000     12.000000
# 50%       64.916000      0.000000    147.000000     17.000000
# ...

# %%
data.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-97-047ed65ff157> in <module>
# ----> 1 data.shape
#
# AttributeError: 'dict' object has no attribute 'shape'

# %%
plt.figure(figsize=(25,16))
x = data.iloc[:]
plt.title("Test")
plt.plot(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-d5eead2e0a08> in <module>
#       1 plt.figure(figsize=(25,16))
# ----> 2 x = data.iloc[:]
#       3 plt.title("Test")
#       4 plt.plot(x)
#
# AttributeError: 'dict' object has no attribute 'iloc'

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc = data['UC']
plt.plot(uc)

# %%
plt.figure(figsize=(25,16))
new = data.copy()
uc_count = data['UC_count']
plt.plot(uc_count)

# %%
fig = plt.figure(figsize=[20, 8])
x = data['UC'].iloc[0:1000]
y = data['UC_count'].iloc[0:1000]
plt.scatter(x, y, s=120)
plt.plot(x, y, color='green', linewidth=2)

# %%
import seaborn as sns
import scipy.stats as stats
data_1 = data['index']
sns.distplot(data_1,bins=5)

# %%
sns.distplot(data['UC_count'],bins=50)
sns.distplot(data['UC'], kde=False, rug=True);

# %%
sns.distplot(data['UC_count'],bins=50)

# %%
UC = data['UC'].iloc[0:16190]
UC_count= data['UC_count'].iloc[0:16190]
sns.jointplot(UC, UC_count)

# %%
sns.pairplot(data[['index', 'UC_count', 'UC']])

# %%
correlation = data.corr()
print(correlation.loc['index', 'UC'])
# Out:
# 0.40577532040723524

# %%
correlation = data.corr()
print(correlation.loc['index', 'UC_count'])
# Out:
# 0.9780029418437288

# %%
correlation = data.corr()
print(correlation.loc['UC_count', 'UC'])
# Out:
# 0.4208923625764789

# %%
corr = np.corrcoef(data['index'], data['UC_count'])
print(corr)
# Out:
# [[1.         0.97800294]
#  [0.97800294 1.        ]]

# %%
r = stats.pearsonr(data['UC'], data['UC_count'])
print(r)
# Out:
# (0.42089236257648566, 0.0)

# %%
r = stats.pearsonr(data['UC_count'], data['UC'])
print(r)
# Out:
# (0.42089236257648566, 0.0)

# %%
r = stats.pearsonr(data['UC'], data['index'])
print(r)
# Out:
# (0.40577532040723546, 0.0)

# %%
r2 = stats.pearsonr(data['UC_count'], data['index'])
print(r)
# Out:
# (0.9780029418437397, 0.0)

# %%
UC = r
UC_count= r2
sns.jointplot(r,r2)

UC = data['UC']
UC_count= data['UC_count'].iloc[0:16190]
sns.jointplot(UC, UC_count)

# %%
UC_count= data['UC_count']
UC = data['index']
sns.jointplot(UC, UC_count)

# %%
UC_count= data['UC']
UC = data['index']
sns.jointplot(UC, UC_count)

# %%
UC_count= data['UC_count']
# index = data['index']
UC = data['UC']
sns.jointplot(UC_count, UC)

# %%
index = data['index'].iloc[:1000]
UC = data['UC'].iloc[:1000]
sns.jointplot(index, UC)

# %%
index = data['index'].iloc[:50000]
UC_count = data['UC_count'].iloc[:50000]
sns.jointplot(index, UC_count)

# %%
# Out:
#          index  dopp   UC  UC_count Manual_Uc_Status
# 0        0.000     0   -1         0               -1
# 1        0.400     0   91         0               -1
# 2        0.900     0   11         0               -1
# 3        0.140     0  262         0               -1
# 4        0.190     0  177         0               -1
# ...        ...   ...  ...       ...              ...
# 25954  129.804     0  178        35
# 25955  129.809     0  170        35
# 25956  129.814     0  162        35
# 25957  129.819     0  166        35
# 25958  129.824     0  179        35
#
# [25959 rows x 5 columns]

# %%
# !pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
# Out:
# Cannot open G:\Anaconda\Scripts\pip-script.py

# %%
fig = plt.figure(figsize=[20, 16])
index = data['index'].iloc[:855]
UC_count = data['UC_count'].iloc[:855]
sns.jointplot((index, UC_count))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-3744506f9e64> in <module>
#       2 index = data['index'].iloc[:855]
#       3 UC_count = data['UC_count'].iloc[:855]
# ----> 4 sns.jointplot(index, UC_count(title='Count: 0 to 855, 1 Min'))
#
# TypeError: 'Series' object is not callable

# %%
sns.boxplot(data=data, x='index', y='UC_count').set(title='Points by Team')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-fe6da70a208b> in <module>
# ----> 1 sns.boxplot(data=data, x='index', y='UC_count').set(title='Points by Team')
#
# G:\Anaconda\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2245     kwargs.update(dict(whis=whis))
#    2246
# -> 2247     plotter.plot(ax, kwargs)
#    2248     return ax
#    2249
#
# G:\Anaconda\lib\site-packages\seaborn\categorical.py in plot(self, ax, boxplot_kws)
#     544     def plot(self, ax, boxplot_kws):
#     545         """Make the plot."""
# --> 546         self.draw_boxplot(ax, boxplot_kws)
#     547         self.annotate_axes(ax)
#     548         if self.orient == "h":
#
# ...

# %%
sns.scatterplot(data=df, x='index', y='UC').set(title='Index vs. UC')
