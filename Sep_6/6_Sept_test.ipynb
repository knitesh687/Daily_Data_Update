# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.reload_library()
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
df3= json.load(open('C:/Users/Acer/Desktop/INDQ/New folder/6_Sept_P3.json'))
df1= json.load(open('C:/Users/Acer/Desktop/INDQ/New folder/6_Sept_P1.json'))
df2= json.load(open('C:/Users/Acer/Desktop/INDQ/New folder/6_Sept_P2.json'))

# %%
data = df3.copy()
del data["raw_data"]["0"]
# data_json["raw_data"]
df = pd.DataFrame(data["raw_data"])

dataf = df.T
data_x = dataf.reset_index()
# data_x = data_x.iloc[:,0]
data_x
file_name = 'p3'
data_x.to_csv(path_or_buf='C:/Users/Acer/Desktop/INDQ/New folder/'+file_name+'.csv')

# %%
df = pd.read_csv('C:/Users/Acer/Desktop/INDQ/New folder/p3.csv')

# %%
df1 = pd.read_csv('C:/Users/Acer/Desktop/INDQ/New folder/p2.csv')

# %%
df2 = pd.read_csv('C:/Users/Acer/Desktop/INDQ/New folder/p1.csv')

# %%
df
# Out:
#         Unnamed: 0     index  ch1  ch2  ch3  dopp  UC  UC_count  \
# 0                0     0.100    0    0  0.0     0  -1         0
# 1                1     0.500    0    0  0.0     0  -1         0
# 2                2     0.100    0    0  0.0     0  -1         0
# 3                3     0.306    0    0  0.0     0  -1         0
# 4                4     0.312    0    0  0.0     0  -1         0
# ...            ...       ...  ...  ...  ...   ...  ..       ...
# 733493      733493  3668.920   90    0  0.0     0   0       149
# 733494      733494  3668.970   90    0  0.0     0   0       149
# 733495      733495  3668.102   90    0  0.0     0   0       149
# 733496      733496  3668.107   90    0  0.0     0   0       149
# 733497      733497  3668.112   90    0  0.0     0   0       149
#
#         Manual_Uc_Status
# 0                     -1
# 1                     -1
# 2                     -1
# 3                     -1
# 4                     -1
# ...                  ...
# ...

# %%
del df['ch1']
del df['ch2']
del df['ch3']
del df['Unnamed: 0']

# %%
df
# Out:
#            index  dopp  UC  UC_count  Manual_Uc_Status
# 0          0.100     0  -1         0                -1
# 1          0.500     0  -1         0                -1
# 2          0.100     0  -1         0                -1
# 3          0.306     0  -1         0                -1
# 4          0.312     0  -1         0                -1
# ...          ...   ...  ..       ...               ...
# 733493  3668.920     0   0       149                -1
# 733494  3668.970     0   0       149                -1
# 733495  3668.102     0   0       149                -1
# 733496  3668.107     0   0       149                -1
# 733497  3668.112     0   0       149                -1
#
# [733498 rows x 5 columns]

# %%
sns.regplot(data=df, x='index', y='UC_count').set(title='Index Vs UC_count')
# Out:
# [Text(0.5, 1.0, 'Index Vs UC_count')]

# %%
sns.regplot(data=df, x='UC', y='UC_count').set(title='UC Vs UC_count')
# Out:
# [Text(0.5, 1.0, 'UC Vs UC_count')]

# %%
sns.regplot(data=df, y='UC', x='UC_count').set(title='UC Vs UC_count')
# Out:
# [Text(0.5, 1.0, 'UC Vs UC_count')]

# %%
fig = plt.figure(figsize=[20, 8])
x = df['index'].iloc[0:66681]
y = df['UC_count'].iloc[0:66681]
plt.title('Index Vs UC_count, 1 Min')
plt.xlabel('Index')
plt.ylabel('UC_count')
plt.scatter(x, y, s=120)
plt.plot(x, y, color='green', linewidth=2)

# %%
fig = plt.figure(figsize=[20, 8])
x = df['index'].iloc[0:333408]
y = df['UC_count'].iloc[0:333408]
plt.title('Index Vs UC_count, 5 Min')
plt.xlabel('Index')
plt.ylabel('UC_count')
plt.scatter(x, y, s=12)
plt.plot(x, y, color='green', linewidth=2)

# %%
fig = plt.figure(figsize=[20, 8])
x = df['index'].iloc[0:666819]
y = df['UC_count'].iloc[0:666819]
plt.title('Index Vs UC_count, 10 Min')
plt.xlabel('Index')
plt.ylabel('UC_count')
plt.scatter(x, y, s=12)
plt.plot(x, y, color='green', linewidth=2)

# %%
fig = plt.figure(figsize=[20, 8])
x = df['index'].iloc[0:666819]
y = df['UC_count'].iloc[0:666819]
plt.title('Index Vs UC_count, 11 Min')
plt.xlabel('Index')
plt.ylabel('UC_count')
plt.scatter(x, y, s=12)
plt.plot(x, y, color='green', linewidth=2)

# %%
plt.figure(figsize=(25,16))
x1= df['UC'].iloc[0:66681]
x2 = df['UC'].iloc[66681:333408]
x3 = df['UC'].iloc[333408:666816]
x4 = df['UC'].iloc[666816:733498]

plt.plot(x1, 'o')
plt.plot(x2, 'y')
plt.plot(x3, 'r')
plt.plot(x4, 'b')

# %%
plt.figure(figsize=(25,16))
x1= df['UC_count'].iloc[0:66681]
x2 = df['UC_count'].iloc[66681:333408]
x3 = df['UC_count'].iloc[333408:666816]
x4 = df['UC_count'].iloc[666816:733498]

plt.plot(x1, 'o')
plt.plot(x2, 'y')
plt.plot(x3, 'r')
plt.plot(x4, 'b')

# %%
plt.figure(figsize=(25,16))
x1= df['UC'].iloc[0:66681]
x2 = df['UC'].iloc[66681:333408]
x3 = df['UC'].iloc[333408:666816]
x4 = df['UC'].iloc[666816:733498]

plt.plot(x1, 'o')
plt.plot(x2, 'y')
plt.plot(x3, 'r')
plt.plot(x4, 'b')

# %%
fig = plt.figure(figsize=[20, 8])
x = df['index'].iloc[:]
y = df['UC'].iloc[:]
plt.title('Index Vs UC,  Min')
plt.xlabel('Index')
plt.ylabel('UC')
plt.scatter(x, y, s=12)
plt.plot(x, y, color='green', linewidth=2)

# %%
fig = plt.figure(figsize=[20, 8])
x = df['index'].iloc[0:66681]
y = df['UC'].iloc[0:66681]
plt.title('Index Vs UC,  Min 1')
plt.xlabel('Index')
plt.ylabel('UC')
plt.scatter(x, y, s=12)
plt.plot(x, y, color='green', linewidth=2)

# %%
fig = plt.figure(figsize=[20, 8])
x = df['index'].iloc[0:333408]
y = df['UC'].iloc[0:333408]
plt.title('Index Vs UC,  Min 5')
plt.xlabel('Index')
plt.ylabel('UC')
plt.scatter(x, y, s=12)
plt.plot(x, y, color='green', linewidth=2)

# %%
fig = plt.figure(figsize=[20, 8])
x = df['index'].iloc[0:666816]
y = df['UC'].iloc[0:666816]
plt.title('Index Vs UC,  Min 10')
plt.xlabel('Index')
plt.ylabel('UC')
plt.scatter(x, y, s=12)
plt.plot(x, y, color='green', linewidth=2)

# %%
fig = plt.figure(figsize=[20, 8])
x = df['index'].iloc[0:733498]
y = df['UC'].iloc[0:733498]
plt.title('Index Vs UC,  Min 11')
plt.xlabel('Index')
plt.ylabel('UC')
plt.scatter(x, y, s=12)
plt.plot(x, y, color='green', linewidth=2)

# %%
fig = plt.figure(figsize=[20, 8])
x = df['UC_count'].iloc[0:]
y = df['UC'].iloc[0:]
plt.title('UC_count Vs UC,  Min')
plt.xlabel('UC_count')
plt.ylabel('UC')
plt.scatter(x, y, s=12)
plt.plot(x, y, color='green', linewidth=2)

# %%
fig = plt.figure(figsize=[20, 8])
x = df['UC_count'].iloc[0:66681]
y = df['UC'].iloc[0:66681]
plt.title('UC_count Vs UC,  Min 1')
plt.xlabel('UC_count')
plt.ylabel('UC')
plt.scatter(x, y, s=12)
plt.plot(x, y, color='green', linewidth=2)

# %%
fig = plt.figure(figsize=[20, 8])
x = df['UC_count'].iloc[0:333408]
y = df['UC'].iloc[0:333408]
plt.title('UC_count Vs UC,  Min 5')
plt.xlabel('UC_count')
plt.ylabel('UC')
plt.scatter(x, y, s=12)
plt.plot(x, y, color='green', linewidth=2)

# %%
fig = plt.figure(figsize=[20, 8])
x = df['UC_count'].iloc[0:666816]
y = df['UC'].iloc[0:666816]
plt.title('UC_count Vs UC,  Min 10')
plt.xlabel('UC_count')
plt.ylabel('UC')
plt.scatter(x, y, s=12)
plt.plot(x, y, color='green', linewidth=2)

# %%
fig = plt.figure(figsize=[20, 8])
x = df['UC_count'].iloc[0:733498]
y = df['UC'].iloc[0:733498]
plt.title('UC_count Vs UC,  Min 11')
plt.xlabel('UC_count')
plt.ylabel('UC')
plt.scatter(x, y, s=12)
plt.plot(x, y, color='green', linewidth=2)

# %%
import seaborn as sns

# %%
sns.pairplot(df[['index', 'UC_count', 'UC']])

# %%
sns.jointplot(index_1, Manual_Uc_Status)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-f77d0f96c1ce> in <module>
# ----> 1 sns.jointplot(index_1, Manual_Uc_Status)
#
# NameError: name 'Manual_Uc_Status' is not defined

# %%
index_1 = df['index'].iloc[:]
UC_count_1 = df['UC_count'].iloc[:]
UC_1 = df['UC'].iloc[:]
sns.jointplot(index_1, UC_count_1)
sns.jointplot(index_1, UC_count_1, kind='hex')
sns.jointplot(index_1, UC_count_1, kind = 'kde')
# Out:
# Count: 0 to 80950, 5 Min

# %%
df.corr()
# Out:
#                      index      dopp        UC  UC_count  Manual_Uc_Status
# index             1.000000 -0.127659  0.163687  0.954980         -0.161302
# dopp             -0.127659  1.000000  0.007636 -0.133738         -0.008228
# UC                0.163687  0.007636  1.000000  0.159138         -0.031293
# UC_count          0.954980 -0.133738  0.159138  1.000000         -0.101093
# Manual_Uc_Status -0.161302 -0.008228 -0.031293 -0.101093          1.000000

# %%
df.corr(method ='pearson')
# Out:
#                      index      dopp        UC  UC_count  Manual_Uc_Status
# index             1.000000 -0.127659  0.163687  0.954980         -0.161302
# dopp             -0.127659  1.000000  0.007636 -0.133738         -0.008228
# UC                0.163687  0.007636  1.000000  0.159138         -0.031293
# UC_count          0.954980 -0.133738  0.159138  1.000000         -0.101093
# Manual_Uc_Status -0.161302 -0.008228 -0.031293 -0.101093          1.000000

# %%
df.corr(method='kendall')
# Out:
#                      index      dopp        UC  UC_count  Manual_Uc_Status
# index             1.000000 -0.176562  0.438987  0.964432         -0.131704
# dopp             -0.176562  1.000000 -0.005997 -0.189138         -0.001038
# UC                0.438987 -0.005997  1.000000  0.455324         -0.137954
# UC_count          0.964432 -0.189138  0.455324  1.000000         -0.109028
# Manual_Uc_Status -0.131704 -0.001038 -0.137954 -0.109028          1.000000

# %%
sns.pairplot(df[['index', 'UC_count', 'Manual_Uc_Status']])

# %%
sns.pairplot(df[['index', 'UC_count', 'Manual_Uc_Status', 'UC']])

# %%
fig = plt.figure(figsize=[20, 8])
x = df['index'].iloc[0:66681]
y = df['UC'].iloc[0:66681]
plt.title('UC_count Vs UC,  Min 1')
plt.xlabel('UC_count')
plt.ylabel('UC')
plt.scatter(x, y, s=12)
plt.plot(x, y, color='green', linewidth=2)

# %%
index_1 = df['index']
UC_1 = df['UC']
sns.jointplot(index_1, UC_1)
sns.jointplot(index_1, UC_1, kind='hex')
sns.jointplot(index_1, UC_1, kind = 'kde')

# %%
plt.rcParams["figure.figsize"] = [20,16]
plt.rcParams["figure.autolayout"] = True
plt.plot(df['Manual_Uc_Status'].iloc[:].values)
