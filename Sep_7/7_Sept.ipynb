# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.reload_library()
from matplotlib import style as style
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
# df= json.load(open('C:/Users/Acer/Desktop/INDQ/New folder/Sep 7/Anakapalli_hsptl_sep7th/pt1_1.json'))
df1= json.load(open('C:/Users/Acer/Desktop/INDQ/New folder/Sep 7/Anakapalli_hsptl_sep7th/pt1_2.json'))

# %%
data = df1.copy()
del data["raw_data"]["0"]
# data_json["raw_data"]
df = pd.DataFrame(data["raw_data"])

dataf = df.T
data_x = dataf.reset_index()
# data_x = data_x.iloc[:,0]
data_x
file_name = 'p2'
data_x.to_csv(path_or_buf='C:/Users/Acer/Desktop/INDQ/New folder/Sep 7/Anakapalli_hsptl_sep7th/'+file_name+'.csv')

# %%
df = pd.read_csv('C:/Users/Acer/Desktop/INDQ/New folder/Sep 7/Anakapalli_hsptl_sep7th/p2.csv')

# %%
df
# Out:
#        Unnamed: 0     index  ch1  ch2     ch3  dopp   UC  UC_count  \
# 0               0   609.868    0    0  2311.0     0  243        20
# 1               1   609.873    0    0  2321.0     0  244        20
# 2               2   609.878    0    0  2313.0     0  243        20
# 3               3   609.883    0    0  2320.0     0  244        20
# 4               4   609.888    0    0  2314.0     0  243        20
# ...           ...       ...  ...  ...     ...   ...  ...       ...
# 86376       86376  1050.267    0    0  2304.0     0  242        20
# 86377       86377  1050.272    0    0  2300.0     0  242        20
# 86378       86378  1050.277    0    0  2307.0     0  242        20
# 86379       86379  1050.282    0    0  2299.0     0  242        20
# 86380       86380  1050.287    0    0  2307.0     0  242        20
#
#        Manual_Uc_Status
# 0                    -1
# 1                    -1
# 2                    -1
# 3                    -1
# 4                    -1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86381 entries, 0 to 86380
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        86381 non-null  int64
#  1   index             86381 non-null  float64
#  2   ch1               86381 non-null  int64
#  3   ch2               86381 non-null  int64
#  4   ch3               86381 non-null  float64
#  5   dopp              86381 non-null  int64
#  6   UC                86381 non-null  int64
#  7   UC_count          86381 non-null  int64
#  8   Manual_Uc_Status  86381 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 5.9 MB

# %%
df.describe()
# Out:
#          Unnamed: 0         index      ch1      ch2           ch3     dopp  \
# count  86381.000000  86381.000000  86381.0  86381.0  86381.000000  86381.0
# mean   43190.000000    834.145367      0.0      0.0   2317.600375      0.0
# std    24936.191139    125.082202      0.0      0.0      9.504384      0.0
# min        0.000000    609.868000      0.0      0.0   2278.000000      0.0
# 25%    21595.000000    726.412000      0.0      0.0   2313.000000      0.0
# 50%    43190.000000    834.393000      0.0      0.0   2320.000000      0.0
# 75%    64785.000000    942.371000      0.0      0.0   2323.000000      0.0
# max    86380.000000   1050.970000      0.0      0.0   2348.000000      0.0
#
#                  UC  UC_count  Manual_Uc_Status
# count  86381.000000   86381.0           86381.0
# mean     243.511200      20.0              -1.0
# std        1.039342       0.0               0.0
# min      239.000000      20.0              -1.0
# 25%      243.000000      20.0              -1.0
# ...

# %%
df.shape
# Out:
# (86381, 9)

# %%
del df['ch1']
del df['ch2']
del df['ch3']
del df['Unnamed: 0']

# %%
df
# Out:
#           index  dopp   UC  UC_count  Manual_Uc_Status
# 0       609.868     0  243        20                -1
# 1       609.873     0  244        20                -1
# 2       609.878     0  243        20                -1
# 3       609.883     0  244        20                -1
# 4       609.888     0  243        20                -1
# ...         ...   ...  ...       ...               ...
# 86376  1050.267     0  242        20                -1
# 86377  1050.272     0  242        20                -1
# 86378  1050.277     0  242        20                -1
# 86379  1050.282     0  242        20                -1
# 86380  1050.287     0  242        20                -1
#
# [86381 rows x 5 columns]

# %%
plt.rcParams["figure.figsize"] = [20,16]
plt.rcParams["figure.autolayout"] = True
plt.plot(df['UC'])
plt.plot(df['Manual_Uc_Status'])
plt.plot(df['UC_count'])
plt.plot(df['index'])
plt.plot(df['dopp'])
#display plot
plt.show()

# %%
plt.rcParams["figure.figsize"] = [20,16]
plt.rcParams["figure.autolayout"] = True
plt.plot(df['UC'].iloc[24000:34000])
plt.plot(df['Manual_Uc_Status'])
plt.plot(df['UC_count'].iloc[25000:34000])
plt.show()

# %%
plt.figure(figsize=(25,16))
x1= df['UC'].iloc[0:14464]
x2 = df['UC'].iloc[14464:28928]
x3 = df['UC'].iloc[28928:43392]
x4 = df['UC'].iloc[43392:57856]

plt.plot(x1, 'o')
plt.plot(x2, 'y')
plt.plot(x3, 'r')
plt.plot(x4, 'b')

# %%
plt.figure(figsize=(25,16))
x1= df['UC'].iloc[9000:14464]
x2 = df['UC'].iloc[14464:16928]
x3 = df['UC'].iloc[28928:43392]
x4 = df['UC'].iloc[43392:57856]

plt.plot(x1, 'o')
plt.plot(x2, 'y')
plt.plot(x3, 'r')
plt.plot(x4, 'b')

# %%
plt.figure(figsize=(25,16))
x1= df['index'].iloc[0:5758]
x2 = df['index'].iloc[5758:11517]
x3 = df['index'].iloc[11517:28790]
x4 = df['index'].iloc[28790:57580]
x5 = df['index'].iloc[57580:86381]

plt.plot(x1, 'o')
plt.plot(x2, 'y')
plt.plot(x3, 'r')
plt.plot(x4, 'b')
plt.plot(x4, 'g')

# %%
x5 = df['UC_count'].iloc[1000:5000]
plt.plot(x5)
