# %% [markdown]
# # Simple Moving Average

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('default')
# %matplotlib inline

# %%
data = pd.read_csv('f_p1.csv',parse_dates=True)
data.head()
# Out:
#    Unnamed: 0  index  ch1  ch2  ch3  dopp  UC  UC_count  Manual_Uc_Status
# 0           0   0.10    0    0  319     0   1         0                 0
# 1           1   0.50    0    0  333     0   0         0                 0
# 2           2   0.12    0    0  323     0   0         0                 0
# 3           3   0.17    0    0  314     0   0         0                 0
# 4           4   0.21    0    0  310     0   0         0                 0

# %%
del data['Unnamed: 0']

# %%
data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370134 entries, 0 to 370133
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             370134 non-null  float64
#  1   ch1               370134 non-null  int64
#  2   ch2               370134 non-null  int64
#  3   ch3               370134 non-null  int64
#  4   dopp              370134 non-null  int64
#  5   UC                370134 non-null  int64
#  6   UC_count          370134 non-null  int64
#  7   Manual_Uc_Status  370134 non-null  int64
# dtypes: float64(1), int64(7)
# memory usage: 22.6 MB

# %% [markdown]
# # Data Slicing 0 to 5000

# %%
df = data['UC'].iloc[0:197].to_frame()

# %% [markdown]
# ### Simple Moving Average: 30

# %%
df['SMA30'] = df['UC'].rolling(30).mean()
# df.dropna(inplace=True)
df
# Out:
#      UC     SMA30
# 0     1       NaN
# 1     0       NaN
# 2     0       NaN
# 3     0       NaN
# 4     0       NaN
# ..   ..       ...
# 192   5  8.800000
# 193   4  8.633333
# 194   0  8.233333
# 195   2  7.933333
# 196   0  7.466667
#
# [197 rows x 2 columns]

# %%
df[['UC', 'SMA30']].plot(label='UC',
                                  figsize=(16, 10))

# %%
df = data['UC'].iloc[197:390].to_frame()
df['SMA30'] = df['UC'].rolling(30).mean()
# df.dropna(inplace=True)
df
df[['UC', 'SMA30']].plot(label='UC',
                                  figsize=(16, 10))

# %%
df = data['UC'].iloc[390:586].to_frame()
df['SMA30'] = df['UC'].rolling(30).mean()
# df.dropna(inplace=True)
df
df[['UC', 'SMA30']].plot(label='UC',
                                  figsize=(16, 10))

# %%
df = data['UC'].iloc[586:781].to_frame()
df['SMA30'] = df['UC'].rolling(30).mean()
# df.dropna(inplace=True)
df
df[['UC', 'SMA30']].plot(label='UC',
                                  figsize=(16, 10))

# %%
df = data['UC'].iloc[781:976].to_frame()
df['SMA30'] = df['UC'].rolling(30).mean()
# df.dropna(inplace=True)
df
df[['UC', 'SMA30']].plot(label='UC',
                                  figsize=(16, 10))

# %%
df = data['UC'].iloc[976:1172].to_frame()
df['SMA30'] = df['UC'].rolling(30).mean()
# df.dropna(inplace=True)
df
df[['UC', 'SMA30']].plot(label='UC',
                                  figsize=(16, 10))

# %%
df = data['UC'].iloc[1172:1370].to_frame()
df['SMA30'] = df['UC'].rolling(30).mean()
# df.dropna(inplace=True)
df
df[['UC', 'SMA30']].plot(label='UC',
                                  figsize=(16, 10))

# %%
df = data['UC'].iloc[1370:1564].to_frame()
df['SMA30'] = df['UC'].rolling(30).mean()
# df.dropna(inplace=True)
df
df[['UC', 'SMA30']].plot(label='UC',
                                  figsize=(16, 10))

# %%
df = data['UC'].iloc[1564:1952].to_frame()
df['SMA30'] = df['UC'].rolling(30).mean()
# df.dropna(inplace=True)
df
df[['UC', 'SMA30']].plot(label='UC',
                                  figsize=(16, 10))

# %%
df = data['UC'].iloc[1952:2149].to_frame()
df['SMA30'] = df['UC'].rolling(30).mean()
# df.dropna(inplace=True)
df
df[['UC', 'SMA30']].plot(label='UC',
                                  figsize=(16, 10))

# %%
df = data['UC'].iloc[0:2149].to_frame()
df['SMA30'] = df['UC'].rolling(30).mean()
# df.dropna(inplace=True)
df
df[['UC', 'SMA30']].plot(label='UC',
                                  figsize=(16, 10))

# %% [markdown]
# ### Dropping Zero or Nan Values

# %%
df['SMA30'] = df['UC'].rolling(30).mean()
df.dropna(inplace=True)
df
# Out:
#       UC     SMA30
# 29     0  2.666667
# 30     0  2.633333
# 31     7  2.866667
# 32     0  2.866667
# 33     2  2.933333
# ...   ..       ...
# 9995   0  0.000000
# 9996   0  0.000000
# 9997   0  0.000000
# 9998   0  0.000000
# 9999   0  0.000000
#
# [9971 rows x 2 columns]

# %%
df = data['UC'].iloc[0:19506].to_frame()

df['SMA30'] = df['UC'].rolling(30).mean()
df['SMA30'] = df['UC'].rolling(30).mean()
# df.dropna(inplace=True)
df
df[['UC', 'SMA30']].plot(label='UC',
                                  figsize=(16, 10))
df
# Out:
#        UC  SMA30
# 0       1    NaN
# 1       0    NaN
# 2       0    NaN
# 3       0    NaN
# 4       0    NaN
# ...    ..    ...
# 19501   0    0.0
# 19502   0    0.0
# 19503   0    0.0
# 19504   0    0.0
# 19505   0    0.0
#
# [19506 rows x 2 columns]

# %%
df['SMA30'] = df['UC'].rolling(30).mean()
# df.dropna(inplace=True)
df
df[['UC', 'SMA30']].plot(label='UC',
                                  figsize=(16, 10))

# %%
df = data['UC'].iloc[19506:39059].to_frame()

df['SMA30'] = df['UC'].rolling(30).mean()
df.dropna(inplace=True)
df
df[['UC', 'SMA30']].plot(label='UC',
                                  figsize=(16, 10))
df
# Out:
#        UC     SMA30
# 19535   0  0.000000
# 19536   0  0.000000
# 19537   0  0.000000
# 19538   0  0.000000
# 19539   0  0.000000
# ...    ..       ...
# 39054   0  0.033333
# 39055   0  0.000000
# 39056   0  0.000000
# 39057   0  0.000000
# 39058   0  0.000000
#
# [19524 rows x 2 columns]

# %%
df = data['UC'].iloc[39059:58634].to_frame()

df['SMA30'] = df['UC'].rolling(30).mean()
df.dropna(inplace=True)
df
df[['UC', 'SMA30']].plot(label='UC',
                                  figsize=(16, 10))
df
# Out:
#        UC     SMA30
# 39088   0  0.000000
# 39089   0  0.000000
# 39090   0  0.000000
# 39091   0  0.000000
# 39092   0  0.000000
# ...    ..       ...
# 58629   5  4.166667
# 58630   5  4.233333
# 58631   5  4.300000
# 58632   5  4.366667
# 58633   5  4.433333
#
# [19546 rows x 2 columns]
